# %%
import sys
sys.path.append("/content/drive/My Drive/snakeAI")

from collections import namedtuple

Experience = namedtuple('Experience', ('state', 'direction', 'next_state', 'reward'))

import tensorflow as tf
import tensorflow.keras as k

from Snake.environment import SnakeMaze
from Snake.variables import Status, Cell
from models.replay_memory import ReplayMemory
from models.model_train import train_dqn
from Snake.utils import euclidean_distance

from datetime import datetime
import numpy as np
import cv2
import os
from time import time

# %% [markdown]
# # ResNet50

# %%
def ResNet50(input_shape, num_not_trainable_blocks=4):
  base_model = k.applications.ResNet50(include_top=False, input_shape=input_shape)
  base_model.trainable = False

  for l in base_model.layers:
    if l.name.split("_")[0] == f"conv{num_not_trainable_blocks+1}":
      break
    l.trainable = True

  model = k.Sequential([
      base_model,
      k.layers.Flatten(),
      k.layers.Dense(4096, activation='relu'),
      k.layers.Dense(2048, activation='relu'),
      k.layers.Dense(1024, activation='relu'),
      k.layers.Dense(4, activation='softmax'),
  ])

  model.build(input_shape=input_shape)
  return model

# %% [markdown]
# ### Configuration

# %%
NUM_NOT_TRAINABLE_BLOCKS = 4

IMAGE_SIZE = (64, 64)
IMAGE_SHAPE = (*IMAGE_SIZE, 3)

learning_rate = 1e-4

config = {
  "num_rolling_avg_sample": 10,
  "evaluate_each": 20,
  "save_models": True,
  "save_graphs": True,
  "gamma": .99,
  "epsilon_decay": 0.005,
  "boundaries": False,
  "maze_width": 10,
  "image_size": IMAGE_SIZE,
  "batch_size": 128,
  "comment": f"""
  Architecture: ResNet50
  Weights: imagenet, {NUM_NOT_TRAINABLE_BLOCKS} non trainable blocks
  Optimizer: Adam
  Hyperparameters:
    lr = {learning_rate}
  Reward:
    if snake.status == Status.DEAD:
        return -1000
        return 0
    else:
        r = 0
        r -= euclidean_distance(envv.snakes[0].body[0], list(envv.food)[0])
        r += 10 if snake.steps_without_food == 1 else 0
        return r
  Reward only for eating food
  """
}

# %% [markdown]
# ### Training

# %%
envv = SnakeMaze(10, 10, 1)
envv.reset()

# %%
def reward(snake, env: SnakeMaze, direction):
    if snake.status == Status.DEAD:
        return -1000
        return 0
    else:
        r = 0
        r -= euclidean_distance(envv.snakes[0].body[0], list(envv.food)[0])
        r += 10 if snake.steps_without_food == 1 else 0
        return r

# %%
t = time()
config["training_dir"] = os.path.join(*['drive', 'My Drive', 'snakeAI', 'trainings', 'transfer_learningDQN', "ResNet50", datetime.now().strftime('%d%h%Y__%H%M%S%f')])
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model = ResNet50(input_shape=IMAGE_SHAPE, num_not_trainable_blocks=NUM_NOT_TRAINABLE_BLOCKS)
model.build(input_shape=(None, *IMAGE_SHAPE))
model.compile(optimizer=optimizer)

model = train_dqn(model, optimizer, reward, **config)
t = time() - t
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# ____________________________________________________________________________________________
# Episode 1 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 1.0
# Replay Memory size: 104
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 2 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.995
# Replay Memory size: 144
#
# ____________________________________________________________________________________________
# Episode 3 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.99
# Replay Memory size: 152
#
# ____________________________________________________________________________________________
# Episode 4 Done!
# Episode reward: -2396.533797690684
# Epsilon: 0.985
# Replay Memory size: 275
#
# ____________________________________________________________________________________________
# Episode 5 Done!
# Episode reward: -1503.1546211727768
# Epsilon: 0.98
# Replay Memory size: 315
#
# ____________________________________________________________________________________________
# Episode 6 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.975
# Replay Memory size: 451
#
# ____________________________________________________________________________________________
# Episode 7 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.97
# Replay Memory size: 459
#
# ____________________________________________________________________________________________
# Episode 8 Done!
# Episode reward: -1711.1142181629361
# Epsilon: 0.965
# Replay Memory size: 492
#
# ____________________________________________________________________________________________
# Episode 9 Done!
# Episode reward: -2343.2233859496373
# Epsilon: 0.96
# Replay Memory size: 416
#
# ____________________________________________________________________________________________
# Episode 10 Done!
# Episode reward: -1970.0505037623097
# Epsilon: 0.955
# Replay Memory size: 419
#
# ____________________________________________________________________________________________
# Episode 11 Done!
# Episode reward: -1493.154621172777
# Epsilon: 0.95
# Replay Memory size: 427
#
# ____________________________________________________________________________________________
# Episode 12 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.945
# Replay Memory size: 307
#
# ____________________________________________________________________________________________
# Episode 13 Done!
# Episode reward: -1493.154621172777
# Epsilon: 0.94
# Replay Memory size: 411
#
# ____________________________________________________________________________________________
# Episode 14 Done!
# Episode reward: -1503.1546211727768
# Epsilon: 0.9349999999999999
# Replay Memory size: 419
#
# ____________________________________________________________________________________________
# Episode 15 Done!
# Episode reward: -2388.91802458482
# Epsilon: 0.9299999999999999
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 16 Done!
# Episode reward: -1604.4933946808414
# Epsilon: 0.9249999999999999
# Replay Memory size: 304
#
# ____________________________________________________________________________________________
# Episode 17 Done!
# Episode reward: -1695.8826719512085
# Epsilon: 0.9199999999999999
# Replay Memory size: 303
#
# ____________________________________________________________________________________________
# Episode 18 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.9149999999999999
# Replay Memory size: 247
#
# ____________________________________________________________________________________________
# Episode 19 Done!
# Episode reward: -2129.9817389854506
# Epsilon: 0.9099999999999999
# Replay Memory size: 271
#
# ____________________________________________________________________________________________
# Episode 20 Done!
# Episode reward: -1848.198134068487
# Epsilon: 0.9049999999999999
# Replay Memory size: 354
#
# ____________________________________________________________________________________________
# Episode 21 Done!
# Episode reward: -2084.287100350268
# Epsilon: 0.8999999999999999
# Replay Memory size: 308
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 22 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.8949999999999999
# Replay Memory size: 348
#
# ____________________________________________________________________________________________
# Episode 23 Done!
# Episode reward: -2160.444831408906
# Epsilon: 0.8899999999999999
# Replay Memory size: 344
#
# ____________________________________________________________________________________________
# Episode 24 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.8849999999999999
# Replay Memory size: 352
#
# ____________________________________________________________________________________________
# Episode 25 Done!
# Episode reward: -1543.56720983393
# Epsilon: 0.8799999999999999
# Replay Memory size: 363
#
# ____________________________________________________________________________________________
# Episode 26 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.8749999999999999
# Replay Memory size: 275
#
# ____________________________________________________________________________________________
# Episode 27 Done!
# Episode reward: -1825.350814750895
# Epsilon: 0.8699999999999999
# Replay Memory size: 355
#
# ____________________________________________________________________________________________
# Episode 28 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.8649999999999999
# Replay Memory size: 331
#
# ____________________________________________________________________________________________
# Episode 29 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.8599999999999999
# Replay Memory size: 275
#
# ____________________________________________________________________________________________
# Episode 30 Done!
# Episode reward: -2259.4498817851354
# Epsilon: 0.8549999999999999
# Replay Memory size: 380
#
# ____________________________________________________________________________________________
# Episode 31 Done!
# Episode reward: -1493.1546211727773
# Epsilon: 0.8499999999999999
# Replay Memory size: 260
#
# ____________________________________________________________________________________________
# Episode 32 Done!
# Episode reward: -1483.1546211727773
# Epsilon: 0.8449999999999999
# Replay Memory size: 300
#
# ____________________________________________________________________________________________
# Episode 33 Done!
# Episode reward: -1939.587411338854
# Epsilon: 0.8399999999999999
# Replay Memory size: 203
#
# ____________________________________________________________________________________________
# Episode 34 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.8349999999999999
# Replay Memory size: 307
#
# ____________________________________________________________________________________________
# Episode 35 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.8299999999999998
# Replay Memory size: 443
#
# ____________________________________________________________________________________________
# Episode 36 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.8249999999999998
# Replay Memory size: 451
#
# ____________________________________________________________________________________________
# Episode 37 Done!
# Episode reward: -1503.1546211727768
# Epsilon: 0.8199999999999998
# Replay Memory size: 299
#
# ____________________________________________________________________________________________
# Episode 38 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.8149999999999998
# Replay Memory size: 275
#
# ____________________________________________________________________________________________
# Episode 39 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.8099999999999998
# Replay Memory size: 251
#
# ____________________________________________________________________________________________
# Episode 40 Done!
# Episode reward: -2091.9028734561316
# Epsilon: 0.8049999999999998
# Replay Memory size: 270
#
# ____________________________________________________________________________________________
# Episode 41 Done!
# Episode reward: -2180.907923832361
# Epsilon: 0.7999999999999998
# Replay Memory size: 398
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 42 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.7949999999999998
# Replay Memory size: 310
#
# ____________________________________________________________________________________________
# Episode 43 Done!
# Episode reward: -2396.5337976906835
# Epsilon: 0.7899999999999998
# Replay Memory size: 241
#
# ____________________________________________________________________________________________
# Episode 44 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.7849999999999998
# Replay Memory size: 345
#
# ____________________________________________________________________________________________
# Episode 45 Done!
# Episode reward: -1535.9514367280663
# Epsilon: 0.7799999999999998
# Replay Memory size: 323
#
# ____________________________________________________________________________________________
# Episode 46 Done!
# Episode reward: -2107.134419667859
# Epsilon: 0.7749999999999998
# Replay Memory size: 312
#
# ____________________________________________________________________________________________
# Episode 47 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.7699999999999998
# Replay Memory size: 448
#
# ____________________________________________________________________________________________
# Episode 48 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.7649999999999998
# Replay Memory size: 264
#
# ____________________________________________________________________________________________
# Episode 49 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.7599999999999998
# Replay Memory size: 208
#
# ____________________________________________________________________________________________
# Episode 50 Done!
# Episode reward: -2411.7653439024116
# Epsilon: 0.7549999999999998
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 51 Done!
# Episode reward: -1503.1546211727768
# Epsilon: 0.7499999999999998
# Replay Memory size: 373
#
# ____________________________________________________________________________________________
# Episode 52 Done!
# Episode reward: -1482.6410249870187
# Epsilon: 0.7449999999999998
# Replay Memory size: 248
#
# ____________________________________________________________________________________________
# Episode 53 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.7399999999999998
# Replay Memory size: 320
#
# ____________________________________________________________________________________________
# Episode 54 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.7349999999999998
# Replay Memory size: 328
#
# ____________________________________________________________________________________________
# Episode 55 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.7299999999999998
# Replay Memory size: 336
#
# ____________________________________________________________________________________________
# Episode 56 Done!
# Episode reward: -1503.1546211727768
# Epsilon: 0.7249999999999998
# Replay Memory size: 344
#
# ____________________________________________________________________________________________
# Episode 57 Done!
# Episode reward: -1723.961537480528
# Epsilon: 0.7199999999999998
# Replay Memory size: 316
#
# ____________________________________________________________________________________________
# Episode 58 Done!
# Episode reward: -2480.307301855186
# Epsilon: 0.7149999999999997
# Replay Memory size: 386
#
# ____________________________________________________________________________________________
# Episode 59 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.7099999999999997
# Replay Memory size: 458
#
# ____________________________________________________________________________________________
# Episode 60 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.7049999999999997
# Replay Memory size: 370
#
# ____________________________________________________________________________________________
# Episode 61 Done!
# Episode reward: -1853.4296802802148
# Epsilon: 0.6999999999999997
# Replay Memory size: 391
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 62 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.6949999999999997
# Replay Memory size: 399
#
# ____________________________________________________________________________________________
# Episode 63 Done!
# Episode reward: -2046.2082348209485
# Epsilon: 0.6899999999999997
# Replay Memory size: 444
#
# ____________________________________________________________________________________________
# Episode 64 Done!
# Episode reward: -1533.56720983393
# Epsilon: 0.6849999999999997
# Replay Memory size: 423
#
# ____________________________________________________________________________________________
# Episode 65 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.6799999999999997
# Replay Memory size: 399
#
# ____________________________________________________________________________________________
# Episode 66 Done!
# Episode reward: -1503.1546211727773
# Epsilon: 0.6749999999999997
# Replay Memory size: 343
#
# ____________________________________________________________________________________________
# Episode 67 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.6699999999999997
# Replay Memory size: 287
#
# ____________________________________________________________________________________________
# Episode 68 Done!
# Episode reward: -2236.602562467544
# Epsilon: 0.6649999999999997
# Replay Memory size: 229
#
# ____________________________________________________________________________________________
# Episode 69 Done!
# Episode reward: -2267.065654890999
# Epsilon: 0.6599999999999997
# Replay Memory size: 367
#
# ____________________________________________________________________________________________
# Episode 70 Done!
# Episode reward: -2396.533797690684
# Epsilon: 0.6549999999999997
# Replay Memory size: 362
#
# ____________________________________________________________________________________________
# Episode 71 Done!
# Episode reward: -1931.9716382329902
# Epsilon: 0.6499999999999997
# Replay Memory size: 296
#
# ____________________________________________________________________________________________
# Episode 72 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.6449999999999997
# Replay Memory size: 336
#
# ____________________________________________________________________________________________
# Episode 73 Done!
# Episode reward: -1503.1546211727768
# Epsilon: 0.6399999999999997
# Replay Memory size: 312
#
# ____________________________________________________________________________________________
# Episode 74 Done!
# Episode reward: -1503.1546211727773
# Epsilon: 0.6349999999999997
# Replay Memory size: 320
#
# ____________________________________________________________________________________________
# Episode 75 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.6299999999999997
# Replay Memory size: 232
#
# ____________________________________________________________________________________________
# Episode 76 Done!
# Episode reward: -1330.3255628697402
# Epsilon: 0.6249999999999997
# Replay Memory size: 247
#
# ____________________________________________________________________________________________
# Episode 77 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.6199999999999997
# Replay Memory size: 383
#
# ____________________________________________________________________________________________
# Episode 78 Done!
# Episode reward: -1368.4044283990597
# Epsilon: 0.6149999999999997
# Replay Memory size: 307
#
# ____________________________________________________________________________________________
# Episode 79 Done!
# Episode reward: -1503.1546211727768
# Epsilon: 0.6099999999999997
# Replay Memory size: 283
#
# ____________________________________________________________________________________________
# Episode 80 Done!
# Episode reward: -1883.8927727036705
# Epsilon: 0.6049999999999996
# Replay Memory size: 372
#
# ____________________________________________________________________________________________
# Episode 81 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.5999999999999996
# Replay Memory size: 348
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 82 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.5949999999999996
# Replay Memory size: 356
#
# ____________________________________________________________________________________________
# Episode 83 Done!
# Episode reward: -1967.6662768681736
# Epsilon: 0.5899999999999996
# Replay Memory size: 360
#
# ____________________________________________________________________________________________
# Episode 84 Done!
# Episode reward: -2472.691528749322
# Epsilon: 0.5849999999999996
# Replay Memory size: 397
#
# ____________________________________________________________________________________________
# Episode 85 Done!
# Episode reward: -1493.1546211727773
# Epsilon: 0.5799999999999996
# Replay Memory size: 309
#
# ____________________________________________________________________________________________
# Episode 86 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.5749999999999996
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 87 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.5699999999999996
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 88 Done!
# Episode reward: -2274.681427996863
# Epsilon: 0.5649999999999996
# Replay Memory size: 240
#
# ____________________________________________________________________________________________
# Episode 89 Done!
# Episode reward: -1503.1546211727768
# Epsilon: 0.5599999999999996
# Replay Memory size: 152
#
# ____________________________________________________________________________________________
# Episode 90 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.5549999999999996
# Replay Memory size: 224
#
# ____________________________________________________________________________________________
# Episode 91 Done!
# Episode reward: -2285.1445204203183
# Epsilon: 0.5499999999999996
# Replay Memory size: 367
#
# ____________________________________________________________________________________________
# Episode 92 Done!
# Episode reward: -2175.6763776206335
# Epsilon: 0.5449999999999996
# Replay Memory size: 237
#
# ____________________________________________________________________________________________
# Episode 93 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.5399999999999996
# Replay Memory size: 213
#
# ____________________________________________________________________________________________
# Episode 94 Done!
# Episode reward: -1503.1546211727773
# Epsilon: 0.5349999999999996
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 95 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.5299999999999996
# Replay Memory size: 261
#
# ____________________________________________________________________________________________
# Episode 96 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.5249999999999996
# Replay Memory size: 333
#
# ____________________________________________________________________________________________
# Episode 97 Done!
# Episode reward: -2487.9230749610497
# Epsilon: 0.5199999999999996
# Replay Memory size: 404
#
# ____________________________________________________________________________________________
# Episode 98 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.5149999999999996
# Replay Memory size: 508
#
# ____________________________________________________________________________________________
# Episode 99 Done!
# Episode reward: -1473.1546211727773
# Epsilon: 0.5099999999999996
# Replay Memory size: 484
#
# ____________________________________________________________________________________________
# Episode 100 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.5049999999999996
# Replay Memory size: 428
#
# ____________________________________________________________________________________________
# Episode 101 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.49999999999999956
# Replay Memory size: 340
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 102 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.49499999999999955
# Replay Memory size: 348
#
# ____________________________________________________________________________________________
# Episode 103 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.48999999999999955
# Replay Memory size: 388
#
# ____________________________________________________________________________________________
# Episode 104 Done!
# Episode reward: -2457.4599825375944
# Epsilon: 0.48499999999999954
# Replay Memory size: 455
#
# ____________________________________________________________________________________________
# Episode 105 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.47999999999999954
# Replay Memory size: 495
#
# ____________________________________________________________________________________________
# Episode 106 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.47499999999999953
# Replay Memory size: 439
#
# ____________________________________________________________________________________________
# Episode 107 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.46999999999999953
# Replay Memory size: 319
#
# ____________________________________________________________________________________________
# Episode 108 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.4649999999999995
# Replay Memory size: 327
#
# ____________________________________________________________________________________________
# Episode 109 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.4599999999999995
# Replay Memory size: 399
#
# ____________________________________________________________________________________________
# Episode 110 Done!
# Episode reward: -1493.154621172777
# Epsilon: 0.4549999999999995
# Replay Memory size: 247
#
# ____________________________________________________________________________________________
# Episode 111 Done!
# Episode reward: -2091.9028734561316
# Epsilon: 0.4499999999999995
# Replay Memory size: 298
#
# ____________________________________________________________________________________________
# Episode 112 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.4449999999999995
# Replay Memory size: 338
#
# ____________________________________________________________________________________________
# Episode 113 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.4399999999999995
# Replay Memory size: 314
#
# ____________________________________________________________________________________________
# Episode 114 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.4349999999999995
# Replay Memory size: 226
#
# ____________________________________________________________________________________________
# Episode 115 Done!
# Episode reward: -2099.5186465619954
# Epsilon: 0.4299999999999995
# Replay Memory size: 246
#
# ____________________________________________________________________________________________
# Episode 116 Done!
# Episode reward: -1493.1546211727773
# Epsilon: 0.4249999999999995
# Replay Memory size: 190
#
# ____________________________________________________________________________________________
# Episode 117 Done!
# Episode reward: -1453.1546211727778
# Epsilon: 0.4199999999999995
# Replay Memory size: 294
#
# ____________________________________________________________________________________________
# Episode 118 Done!
# Episode reward: -1493.1546211727773
# Epsilon: 0.4149999999999995
# Replay Memory size: 398
#
# ____________________________________________________________________________________________
# Episode 119 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.4099999999999995
# Replay Memory size: 310
#
# ____________________________________________________________________________________________
# Episode 120 Done!
# Episode reward: -1483.1546211727773
# Epsilon: 0.40499999999999947
# Replay Memory size: 318
#
# ____________________________________________________________________________________________
# Episode 121 Done!
# Episode reward: -2129.9817389854506
# Epsilon: 0.39999999999999947
# Replay Memory size: 246
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 122 Done!
# Episode reward: -1503.1546211727773
# Epsilon: 0.39499999999999946
# Replay Memory size: 254
#
# ____________________________________________________________________________________________
# Episode 123 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.38999999999999946
# Replay Memory size: 166
#
# ____________________________________________________________________________________________
# Episode 124 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.38499999999999945
# Replay Memory size: 302
#
# ____________________________________________________________________________________________
# Episode 125 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.37999999999999945
# Replay Memory size: 342
#
# ____________________________________________________________________________________________
# Episode 126 Done!
# Episode reward: -1490.2567980928825
# Epsilon: 0.37499999999999944
# Replay Memory size: 410
#
# ____________________________________________________________________________________________
# Episode 127 Done!
# Episode reward: -1503.1546211727768
# Epsilon: 0.36999999999999944
# Replay Memory size: 514
#
# ____________________________________________________________________________________________
# Episode 128 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.36499999999999944
# Replay Memory size: 362
#
# ____________________________________________________________________________________________
# Episode 129 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.35999999999999943
# Replay Memory size: 338
#
# ____________________________________________________________________________________________
# Episode 130 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.3549999999999994
# Replay Memory size: 282
#
# ____________________________________________________________________________________________
# Episode 131 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.3499999999999994
# Replay Memory size: 354
#
# ____________________________________________________________________________________________
# Episode 132 Done!
# Episode reward: -1473.1546211727773
# Epsilon: 0.3449999999999994
# Replay Memory size: 234
#
# ____________________________________________________________________________________________
# Episode 133 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.3399999999999994
# Replay Memory size: 306
#
# ____________________________________________________________________________________________
# Episode 134 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.3349999999999994
# Replay Memory size: 346
#
# ____________________________________________________________________________________________
# Episode 135 Done!
# Episode reward: -2023.3609155033573
# Epsilon: 0.3299999999999994
# Replay Memory size: 260
#
# ____________________________________________________________________________________________
# Episode 136 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.3249999999999994
# Replay Memory size: 268
#
# ____________________________________________________________________________________________
# Episode 137 Done!
# Episode reward: -1503.1546211727773
# Epsilon: 0.3199999999999994
# Replay Memory size: 116
#
# ____________________________________________________________________________________________
# Episode 138 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.3149999999999994
# Replay Memory size: 252
#
# ____________________________________________________________________________________________
# Episode 139 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.3099999999999994
# Replay Memory size: 324
#
# ____________________________________________________________________________________________
# Episode 140 Done!
# Episode reward: -1503.1546211727773
# Epsilon: 0.3049999999999994
# Replay Memory size: 300
#
# ____________________________________________________________________________________________
# Episode 141 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.2999999999999994
# Replay Memory size: 276
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 142 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.2949999999999994
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 143 Done!
# Episode reward: -1503.1546211727773
# Epsilon: 0.28999999999999937
# Replay Memory size: 260
#
# ____________________________________________________________________________________________
# Episode 144 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.28499999999999936
# Replay Memory size: 236
#
# ____________________________________________________________________________________________
# Episode 145 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.27999999999999936
# Replay Memory size: 148
#
# ____________________________________________________________________________________________
# Episode 146 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.27499999999999936
# Replay Memory size: 252
#
# ____________________________________________________________________________________________
# Episode 147 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.26999999999999935
# Replay Memory size: 228
#
# ____________________________________________________________________________________________
# Episode 148 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.26499999999999935
# Replay Memory size: 268
#
# ____________________________________________________________________________________________
# Episode 149 Done!
# Episode reward: -1802.5034954333032
# Epsilon: 0.25999999999999934
# Replay Memory size: 281
#
# ____________________________________________________________________________________________
# Episode 150 Done!
# Episode reward: -2221.3710162558164
# Epsilon: 0.25499999999999934
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 151 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.24999999999999933
# Replay Memory size: 261
#
# ____________________________________________________________________________________________
# Episode 152 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.24499999999999933
# Replay Memory size: 333
#
# ____________________________________________________________________________________________
# Episode 153 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.23999999999999932
# Replay Memory size: 405
#
# ____________________________________________________________________________________________
# Episode 154 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.23499999999999932
# Replay Memory size: 477
#
# ____________________________________________________________________________________________
# Episode 155 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.22999999999999932
# Replay Memory size: 421
#
# ____________________________________________________________________________________________
# Episode 156 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.2249999999999993
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 157 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.2199999999999993
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 158 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.2149999999999993
# Replay Memory size: 253
#
# ____________________________________________________________________________________________
# Episode 159 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.2099999999999993
# Replay Memory size: 293
#
# ____________________________________________________________________________________________
# Episode 160 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.2049999999999993
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 161 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.1999999999999993
# Replay Memory size: 309
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 162 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.19499999999999929
# Replay Memory size: 381
#
# ____________________________________________________________________________________________
# Episode 163 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.18999999999999928
# Replay Memory size: 357
#
# ____________________________________________________________________________________________
# Episode 164 Done!
# Episode reward: -1493.1546211727773
# Epsilon: 0.18499999999999928
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 165 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.17999999999999927
# Replay Memory size: 277
#
# ____________________________________________________________________________________________
# Episode 166 Done!
# Episode reward: -1493.1546211727773
# Epsilon: 0.17499999999999927
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 167 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.16999999999999926
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 168 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.16499999999999926
# Replay Memory size: 397
#
# ____________________________________________________________________________________________
# Episode 169 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.15999999999999925
# Replay Memory size: 373
#
# ____________________________________________________________________________________________
# Episode 170 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.15499999999999925
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 171 Done!
# Episode reward: -1503.1546211727773
# Epsilon: 0.14999999999999925
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 172 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.14499999999999924
# Replay Memory size: 429
#
# ____________________________________________________________________________________________
# Episode 173 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.13999999999999924
# Replay Memory size: 405
#
# ____________________________________________________________________________________________
# Episode 174 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.13499999999999923
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 175 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.12999999999999923
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 176 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.12499999999999922
# Replay Memory size: 429
#
# ____________________________________________________________________________________________
# Episode 177 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.11999999999999922
# Replay Memory size: 373
#
# ____________________________________________________________________________________________
# Episode 178 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.11499999999999921
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 179 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.10999999999999921
# Replay Memory size: 293
#
# ____________________________________________________________________________________________
# Episode 180 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.1049999999999992
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 181 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.0999999999999992
# Replay Memory size: 309
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 182 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.0949999999999992
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 183 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.08999999999999919
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 184 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.08499999999999919
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 185 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.07999999999999918
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 186 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.07499999999999918
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 187 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.06999999999999917
# Replay Memory size: 357
#
# ____________________________________________________________________________________________
# Episode 188 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.06499999999999917
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 189 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.05999999999999917
# Replay Memory size: 405
#
# ____________________________________________________________________________________________
# Episode 190 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.054999999999999175
# Replay Memory size: 413
#
# ____________________________________________________________________________________________
# Episode 191 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.04999999999999918
# Replay Memory size: 421
#
# ____________________________________________________________________________________________
# Episode 192 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.04499999999999918
# Replay Memory size: 461
#
# ____________________________________________________________________________________________
# Episode 193 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.03999999999999918
# Replay Memory size: 373
#
# ____________________________________________________________________________________________
# Episode 194 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.034999999999999185
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 195 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.029999999999999184
# Replay Memory size: 261
#
# ____________________________________________________________________________________________
# Episode 196 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.024999999999999183
# Replay Memory size: 333
#
# ____________________________________________________________________________________________
# Episode 197 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01999999999999918
# Replay Memory size: 245
#
# ____________________________________________________________________________________________
# Episode 198 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01499999999999918
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 199 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 293
#
# ____________________________________________________________________________________________
# Episode 200 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 201 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 309
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 202 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 203 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 261
#
# ____________________________________________________________________________________________
# Episode 204 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 205 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 277
#
# ____________________________________________________________________________________________
# Episode 206 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.01
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 207 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 421
#
# ____________________________________________________________________________________________
# Episode 208 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 461
#
# ____________________________________________________________________________________________
# Episode 209 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 469
#
# ____________________________________________________________________________________________
# Episode 210 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 445
#
# ____________________________________________________________________________________________
# Episode 211 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 357
#
# ____________________________________________________________________________________________
# Episode 212 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 429
#
# ____________________________________________________________________________________________
# Episode 213 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 437
#
# ____________________________________________________________________________________________
# Episode 214 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 215 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 229
#
# ____________________________________________________________________________________________
# Episode 216 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 333
#
# ____________________________________________________________________________________________
# Episode 217 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 373
#
# ____________________________________________________________________________________________
# Episode 218 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 219 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 220 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.01
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 221 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 373
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 222 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 223 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 357
#
# ____________________________________________________________________________________________
# Episode 224 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 225 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 226 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 221
#
# ____________________________________________________________________________________________
# Episode 227 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 293
#
# ____________________________________________________________________________________________
# Episode 228 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 229 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 405
#
# ...
# Replay Memory size: 421
#
# ____________________________________________________________________________________________
# Episode 484 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 485 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 277
#
# ____________________________________________________________________________________________
# Episode 486 Done!
# Episode reward: -1513.154621172777
# Epsilon: 0.01
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 487 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 229
#
# ____________________________________________________________________________________________
# Episode 488 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 397
#
# ____________________________________________________________________________________________
# Episode 489 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 490 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 491 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 293
#
# ____________________________________________________________________________________________
# Episode 492 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 493 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 245
#
# ____________________________________________________________________________________________
# Episode 494 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 189
#
# ____________________________________________________________________________________________
# Episode 495 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 229
#
# ____________________________________________________________________________________________
# Episode 496 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 205
#
# ____________________________________________________________________________________________
# Episode 497 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 498 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 499 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 261
#
# ____________________________________________________________________________________________
# Episode 500 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 501 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 341
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# /content/drive/My Drive/snakeAI/Snake/utils.py:56: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, (ax1, ax2) = plt.subplots(2, 1)
# Episode 502 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 445
#
# ____________________________________________________________________________________________
# Episode 503 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 421
#
# ____________________________________________________________________________________________
# Episode 504 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 429
#
# ____________________________________________________________________________________________
# Episode 505 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 277
#
# ____________________________________________________________________________________________
# Episode 506 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 253
#
# ____________________________________________________________________________________________
# Episode 507 Done!
# Episode reward: -1503.154621172777
# Epsilon: 0.01
# Replay Memory size: 229
#
# ____________________________________________________________________________________________
# Episode 508 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 205
#
# ____________________________________________________________________________________________
# Episode 509 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 245
#
# ____________________________________________________________________________________________
# Episode 510 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 511 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 165
#
# ____________________________________________________________________________________________
# Episode 512 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 513 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 514 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 515 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 261
#
# ____________________________________________________________________________________________
# Episode 516 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 237
#
# ____________________________________________________________________________________________
# Episode 517 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 245
#
# ____________________________________________________________________________________________
# Episode 518 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 381
#
# ____________________________________________________________________________________________
# Episode 519 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 520 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 521 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 373
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# /content/drive/My Drive/snakeAI/Snake/utils.py:56: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, (ax1, ax2) = plt.subplots(2, 1)
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 522 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 523 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 524 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 525 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 526 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 527 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 528 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 333
#
# ____________________________________________________________________________________________
# Episode 529 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 405
#
# ____________________________________________________________________________________________
# Episode 530 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 531 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 261
#
# ____________________________________________________________________________________________
# Episode 532 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 533 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 309
#
# ____________________________________________________________________________________________
# Episode 534 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 445
#
# ____________________________________________________________________________________________
# Episode 535 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 536 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 333
#
# ____________________________________________________________________________________________
# Episode 537 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 538 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 381
#
# ____________________________________________________________________________________________
# Episode 539 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 229
#
# ____________________________________________________________________________________________
# Episode 540 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 541 Done!
# Episode reward: -1503.1546211727773
# Epsilon: 0.01
# Replay Memory size: 341
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/model
# /content/drive/My Drive/snakeAI/Snake/utils.py:56: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, (ax1, ax2) = plt.subplots(2, 1)
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__220852167213/Reward.png
# ____________________________________________________________________________________________
# Episode 542 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 543 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 544 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 545 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 437
#
# ____________________________________________________________________________________________
# Episode 546 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 413
#
# ____________________________________________________________________________________________
# Episode 547 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 261
#
# ____________________________________________________________________________________________
# Episode 548 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 549 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 405
#
# ____________________________________________________________________________________________
# Episode 550 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 477
#
# ____________________________________________________________________________________________
# Episode 551 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 552 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 525
#
# ____________________________________________________________________________________________
# Episode 553 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 437
#
# ____________________________________________________________________________________________
# Episode 554 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 413
#
# ____________________________________________________________________________________________
# Episode 555 Done!
# Episode reward: -1513.1546211727768
# Epsilon: 0.01
# Replay Memory size: 357
#
# ____________________________________________________________________________________________
# Episode 556 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 397
#
# ____________________________________________________________________________________________
# Episode 557 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 405
#
# ____________________________________________________________________________________________
# Episode 558 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 559 Done!
# Episode reward: -1523.1546211727768
# Epsilon: 0.01
# Replay Memory size: 325
#
# ____________________________________________________________________________________________

# %%
assert False
env = SnakeMaze(20, 20, 1, with_boundaries=False)
env.reset()
imgs = []
while env.num_active_agents:
    imgs.append(env.snake_matrices[0])
    # state = resize_image(env.snake_matrices[0], IMAGE_SIZE)
    direction = np.argmax(model(np.array([state])))
    env.step({0: direction})

# %%
generate_animation(imgs)
