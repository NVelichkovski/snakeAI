# %%
import sys
sys.path.append("/content/drive/My Drive/snakeAI")

from collections import namedtuple

Experience = namedtuple('Experience', ('state', 'direction', 'next_state', 'reward'))

import tensorflow as tf
import tensorflow.keras as k

from Snake.environment import SnakeMaze
from Snake.variables import Status, Cell
from models.replay_memory import ReplayMemory
from models.model_train import train_dqn
from Snake.utils import euclidean_distance

from datetime import datetime
import numpy as np
import cv2
import os
from time import time

# %% [markdown]
# # ResNet50

# %%
def ResNet50(input_shape, num_not_trainable_blocks=4):
  base_model = k.applications.ResNet50(include_top=False, input_shape=input_shape)
  base_model.trainable = False

  for l in base_model.layers:
    if l.name.split("_")[0] == f"conv{num_not_trainable_blocks+1}":
      break
    l.trainable = True

  model = k.Sequential([
      base_model,
      k.layers.Flatten(),
      k.layers.Dense(4096, activation='relu'),
      k.layers.Dense(2048, activation='relu'),
      k.layers.Dense(1024, activation='relu'),
      k.layers.Dense(4, activation='softmax'),
  ])

  model.build(input_shape=input_shape)
  return model

# %% [markdown]
# ### Configuration

# %%
NUM_NOT_TRAINABLE_BLOCKS = 4

IMAGE_SIZE = (64, 64)
IMAGE_SHAPE = (*IMAGE_SIZE, 3)

learning_rate = 1e-4

config = {
  "num_rolling_avg_sample": 10,
  "evaluate_each": 20,
  "save_models": True,
  "save_graphs": True,
  "gamma": .95,
  "epsilon_decay": 0.005,
  "boundaries": False,
  "maze_width": 10,
  "image_size": IMAGE_SIZE,
  "comment": f"""
  Architecture: ResNet50
  Weights: imagenet, {NUM_NOT_TRAINABLE_BLOCKS} non trainable blocks
  Optimizer: Adam
  Hyperparameters:
    lr = {learning_rate}
  Reward:
      if snake.status == Status.DEAD:
        return 0
    else:
        r = 0
        r += 1000 if snake.steps_without_food == 1 else 0
        return r

  Reward only for eating food
  """
}

# %% [markdown]
# ### Training

# %%
envv = SnakeMaze(10, 10, 1)
envv.reset()

# %%
def reward(snake, env: SnakeMaze, direction):
    if snake.status == Status.DEAD:
        # return -1000
        return 0
    else:
        r = 0
        r -= euclidean_distance(envv.snakes[0].body[0], list(envv.food)[0])
        r += 10 if snake.steps_without_food == 1 else 0
        return r

# %%
t = time()
config["training_dir"] = os.path.join(*['drive', 'My Drive', 'snakeAI', 'trainings', 'transfer_learningDQN', "ResNet50", datetime.now().strftime('%d%h%Y__%H%M%S%f')])
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model = ResNet50(input_shape=IMAGE_SHAPE, num_not_trainable_blocks=NUM_NOT_TRAINABLE_BLOCKS)
model.build(input_shape=(None, *IMAGE_SHAPE))
model.compile(optimizer=optimizer)

model = train_dqn(model, optimizer, reward, **config)
t = time() - t
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# ____________________________________________________________________________________________
# Episode 1 Done!
# Episode reward: -565.6854249492402
# Epsilon: 1.0
# Replay Memory size: 136
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode0
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 2 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.995
# Replay Memory size: 304
#
# ____________________________________________________________________________________________
# Episode 3 Done!
# Episode reward: -443.8620484583764
# Epsilon: 0.99
# Replay Memory size: 181
#
# ____________________________________________________________________________________________
# Episode 4 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.985
# Replay Memory size: 253
#
# ____________________________________________________________________________________________
# Episode 5 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.98
# Replay Memory size: 133
#
# ____________________________________________________________________________________________
# Episode 6 Done!
# Episode reward: -161.01933598375598
# Epsilon: 0.975
# Replay Memory size: 198
#
# ____________________________________________________________________________________________
# Episode 7 Done!
# Episode reward: -293.955410846827
# Epsilon: 0.97
# Replay Memory size: 278
#
# ____________________________________________________________________________________________
# Episode 8 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.965
# Replay Memory size: 254
#
# ____________________________________________________________________________________________
# Episode 9 Done!
# Episode reward: -144.0487732352789
# Epsilon: 0.96
# Replay Memory size: 249
#
# ____________________________________________________________________________________________
# Episode 10 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.955
# Replay Memory size: 289
#
# ____________________________________________________________________________________________
# Episode 11 Done!
# Episode reward: -494.77373670380837
# Epsilon: 0.95
# Replay Memory size: 280
#
# ____________________________________________________________________________________________
# Episode 12 Done!
# Episode reward: -265.6711395993649
# Epsilon: 0.945
# Replay Memory size: 318
#
# ____________________________________________________________________________________________
# Episode 13 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.94
# Replay Memory size: 390
#
# ____________________________________________________________________________________________
# Episode 14 Done!
# Episode reward: -489.11688245431594
# Epsilon: 0.9349999999999999
# Replay Memory size: 411
#
# ____________________________________________________________________________________________
# Episode 15 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.9299999999999999
# Replay Memory size: 387
#
# ____________________________________________________________________________________________
# Episode 16 Done!
# Episode reward: -487.6021638285546
# Epsilon: 0.9249999999999999
# Replay Memory size: 347
#
# ____________________________________________________________________________________________
# Episode 17 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.9199999999999999
# Replay Memory size: 483
#
# ____________________________________________________________________________________________
# Episode 18 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.9149999999999999
# Replay Memory size: 491
#
# ____________________________________________________________________________________________
# Episode 19 Done!
# Episode reward: -322.23968209428926
# Epsilon: 0.9099999999999999
# Replay Memory size: 485
#
# ____________________________________________________________________________________________
# Episode 20 Done!
# Episode reward: -296.78383797157335
# Epsilon: 0.9049999999999999
# Replay Memory size: 438
#
# ____________________________________________________________________________________________
# Episode 21 Done!
# Episode reward: -364.46507883870584
# Epsilon: 0.8999999999999999
# Replay Memory size: 454
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode20
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 22 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.8949999999999999
# Replay Memory size: 238
#
# ____________________________________________________________________________________________
# Episode 23 Done!
# Episode reward: -418.4062043356605
# Epsilon: 0.8899999999999999
# Replay Memory size: 266
#
# ____________________________________________________________________________________________
# Episode 24 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.8849999999999999
# Replay Memory size: 274
#
# ____________________________________________________________________________________________
# Episode 25 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.8799999999999999
# Replay Memory size: 378
#
# ____________________________________________________________________________________________
# Episode 26 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.8749999999999999
# Replay Memory size: 354
#
# ____________________________________________________________________________________________
# Episode 27 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.8699999999999999
# Replay Memory size: 362
#
# ____________________________________________________________________________________________
# Episode 28 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.8649999999999999
# Replay Memory size: 338
#
# ____________________________________________________________________________________________
# Episode 29 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.8599999999999999
# Replay Memory size: 410
#
# ____________________________________________________________________________________________
# Episode 30 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.8549999999999999
# Replay Memory size: 322
#
# ____________________________________________________________________________________________
# Episode 31 Done!
# Episode reward: -129.90663761154795
# Epsilon: 0.8499999999999999
# Replay Memory size: 344
#
# ____________________________________________________________________________________________
# Episode 32 Done!
# Episode reward: -452.3473298326152
# Epsilon: 0.8449999999999999
# Replay Memory size: 320
#
# ____________________________________________________________________________________________
# Episode 33 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.8399999999999999
# Replay Memory size: 360
#
# ____________________________________________________________________________________________
# Episode 34 Done!
# Episode reward: -251.52900397563388
# Epsilon: 0.8349999999999999
# Replay Memory size: 393
#
# ____________________________________________________________________________________________
# Episode 35 Done!
# Episode reward: -260.01428534987247
# Epsilon: 0.8299999999999998
# Replay Memory size: 429
#
# ____________________________________________________________________________________________
# Episode 36 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.8249999999999998
# Replay Memory size: 373
#
# ____________________________________________________________________________________________
# Episode 37 Done!
# Episode reward: -282.64170234784217
# Epsilon: 0.8199999999999998
# Replay Memory size: 385
#
# ____________________________________________________________________________________________
# Episode 38 Done!
# Episode reward: -535.6854249492401
# Epsilon: 0.8149999999999998
# Replay Memory size: 361
#
# ____________________________________________________________________________________________
# Episode 39 Done!
# Episode reward: -243.04372260139533
# Epsilon: 0.8099999999999998
# Replay Memory size: 359
#
# ____________________________________________________________________________________________
# Episode 40 Done!
# Episode reward: -334.86709909225897
# Epsilon: 0.8049999999999998
# Replay Memory size: 297
#
# ____________________________________________________________________________________________
# Episode 41 Done!
# Episode reward: -521.543289325509
# Epsilon: 0.7999999999999998
# Replay Memory size: 429
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode40
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 42 Done!
# Episode reward: -535.6854249492401
# Epsilon: 0.7949999999999998
# Replay Memory size: 373
#
# ____________________________________________________________________________________________
# Episode 43 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.7899999999999998
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 44 Done!
# Episode reward: -401.4356415871831
# Epsilon: 0.7849999999999998
# Replay Memory size: 339
#
# ____________________________________________________________________________________________
# Episode 45 Done!
# Episode reward: -45.05382386916239
# Epsilon: 0.7799999999999998
# Replay Memory size: 363
#
# ____________________________________________________________________________________________
# Episode 46 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.7749999999999998
# Replay Memory size: 371
#
# ____________________________________________________________________________________________
# Episode 47 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.7699999999999998
# Replay Memory size: 379
#
# ____________________________________________________________________________________________
# Episode 48 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.7649999999999998
# Replay Memory size: 387
#
# ____________________________________________________________________________________________
# Episode 49 Done!
# Episode reward: -545.68542494924
# Epsilon: 0.7599999999999998
# Replay Memory size: 363
#
# ____________________________________________________________________________________________
# Episode 50 Done!
# Episode reward: -535.6854249492402
# Epsilon: 0.7549999999999998
# Replay Memory size: 307
#
# ____________________________________________________________________________________________
# Episode 51 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.7499999999999998
# Replay Memory size: 315
#
# ____________________________________________________________________________________________
# Episode 52 Done!
# Episode reward: -415.5777772109143
# Epsilon: 0.7449999999999998
# Replay Memory size: 278
#
# ____________________________________________________________________________________________
# Episode 53 Done!
# Episode reward: -514.5727265770316
# Epsilon: 0.7399999999999998
# Replay Memory size: 212
#
# ____________________________________________________________________________________________
# Episode 54 Done!
# Episode reward: -491.94530957906204
# Epsilon: 0.7349999999999998
# Replay Memory size: 266
#
# ____________________________________________________________________________________________
# Episode 55 Done!
# Episode reward: -535.6854249492402
# Epsilon: 0.7299999999999998
# Replay Memory size: 242
#
# ____________________________________________________________________________________________
# Episode 56 Done!
# Episode reward: -367.29350596345193
# Epsilon: 0.7249999999999998
# Replay Memory size: 291
#
# ____________________________________________________________________________________________
# Episode 57 Done!
# Episode reward: -392.9503602129445
# Epsilon: 0.7199999999999998
# Replay Memory size: 278
#
# ____________________________________________________________________________________________
# Episode 58 Done!
# Episode reward: -542.856997824494
# Epsilon: 0.7149999999999997
# Replay Memory size: 318
#
# ____________________________________________________________________________________________
# Episode 59 Done!
# Episode reward: -545.6854249492402
# Epsilon: 0.7099999999999997
# Replay Memory size: 230
#
# ____________________________________________________________________________________________
# Episode 60 Done!
# Episode reward: -310.9259735953044
# Epsilon: 0.7049999999999997
# Replay Memory size: 348
#
# ____________________________________________________________________________________________
# Episode 61 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.6999999999999997
# Replay Memory size: 388
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode60
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 62 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.6949999999999997
# Replay Memory size: 460
#
# ____________________________________________________________________________________________
# Episode 63 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.6899999999999997
# Replay Memory size: 468
#
# ____________________________________________________________________________________________
# Episode 64 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.6849999999999997
# Replay Memory size: 380
#
# ____________________________________________________________________________________________
# Episode 65 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.6799999999999997
# Replay Memory size: 388
#
# ____________________________________________________________________________________________
# Episode 66 Done!
# Episode reward: -446.69047558312275
# Epsilon: 0.6749999999999997
# Replay Memory size: 458
#
# ____________________________________________________________________________________________
# Episode 67 Done!
# Episode reward: -306.38181771801993
# Epsilon: 0.6699999999999997
# Replay Memory size: 393
#
# ____________________________________________________________________________________________
# Episode 68 Done!
# Episode reward: -268.4995667241111
# Epsilon: 0.6649999999999997
# Replay Memory size: 336
#
# ____________________________________________________________________________________________
# Episode 69 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.6599999999999997
# Replay Memory size: 376
#
# ____________________________________________________________________________________________
# Episode 70 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.6549999999999997
# Replay Memory size: 288
#
# ____________________________________________________________________________________________
# Episode 71 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.6499999999999997
# Replay Memory size: 392
#
# ____________________________________________________________________________________________
# Episode 72 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.6449999999999997
# Replay Memory size: 336
#
# ____________________________________________________________________________________________
# Episode 73 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.6399999999999997
# Replay Memory size: 312
#
# ____________________________________________________________________________________________
# Episode 74 Done!
# Episode reward: -412.7493500861681
# Epsilon: 0.6349999999999997
# Replay Memory size: 242
#
# ____________________________________________________________________________________________
# Episode 75 Done!
# Episode reward: -535.6854249492402
# Epsilon: 0.6299999999999997
# Replay Memory size: 282
#
# ____________________________________________________________________________________________
# Episode 76 Done!
# Episode reward: -511.5432893255089
# Epsilon: 0.6249999999999997
# Replay Memory size: 318
#
# ____________________________________________________________________________________________
# Episode 77 Done!
# Episode reward: -473.4600282048235
# Epsilon: 0.6199999999999997
# Replay Memory size: 273
#
# ____________________________________________________________________________________________
# Episode 78 Done!
# Episode reward: -438.20519420888394
# Epsilon: 0.6149999999999997
# Replay Memory size: 340
#
# ____________________________________________________________________________________________
# Episode 79 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.6099999999999997
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 80 Done!
# Episode reward: -525.6854249492402
# Epsilon: 0.6049999999999996
# Replay Memory size: 324
#
# ____________________________________________________________________________________________
# Episode 81 Done!
# Episode reward: -105.76450198781704
# Epsilon: 0.5999999999999996
# Replay Memory size: 373
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode80
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 82 Done!
# Episode reward: -535.6854249492402
# Epsilon: 0.5949999999999996
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 83 Done!
# Episode reward: -438.2051942088839
# Epsilon: 0.5899999999999996
# Replay Memory size: 288
#
# ____________________________________________________________________________________________
# Episode 84 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.5849999999999996
# Replay Memory size: 104
#
# ____________________________________________________________________________________________
# Episode 85 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.5799999999999996
# Replay Memory size: 144
#
# ____________________________________________________________________________________________
# Episode 86 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.5749999999999996
# Replay Memory size: 280
#
# ____________________________________________________________________________________________
# Episode 87 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.5699999999999996
# Replay Memory size: 288
#
# ____________________________________________________________________________________________
# Episode 88 Done!
# Episode reward: -207.5878784786797
# Epsilon: 0.5649999999999996
# Replay Memory size: 277
#
# ____________________________________________________________________________________________
# Episode 89 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.5599999999999996
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 90 Done!
# Episode reward: -513.0580079512704
# Epsilon: 0.5549999999999996
# Replay Memory size: 286
#
# ____________________________________________________________________________________________
# Episode 91 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.5499999999999996
# Replay Memory size: 262
#
# ____________________________________________________________________________________________
# Episode 92 Done!
# Episode reward: -432.54833995939157
# Epsilon: 0.5449999999999996
# Replay Memory size: 263
#
# ____________________________________________________________________________________________
# Episode 93 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.5399999999999996
# Replay Memory size: 303
#
# ____________________________________________________________________________________________
# Episode 94 Done!
# Episode reward: -535.6854249492401
# Epsilon: 0.5349999999999996
# Replay Memory size: 279
#
# ____________________________________________________________________________________________
# Episode 95 Done!
# Episode reward: -381.63665171395974
# Epsilon: 0.5299999999999996
# Replay Memory size: 262
#
# ____________________________________________________________________________________________
# Episode 96 Done!
# Episode reward: -525.8864350760166
# Epsilon: 0.5249999999999996
# Replay Memory size: 328
#
# ____________________________________________________________________________________________
# Episode 97 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.5199999999999996
# Replay Memory size: 336
#
# ____________________________________________________________________________________________
# Episode 98 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.5149999999999996
# Replay Memory size: 344
#
# ____________________________________________________________________________________________
# Episode 99 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.5099999999999996
# Replay Memory size: 288
#
# ____________________________________________________________________________________________
# Episode 100 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.5049999999999996
# Replay Memory size: 296
#
# ____________________________________________________________________________________________
# Episode 101 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.49999999999999956
# Replay Memory size: 304
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode100
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 102 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.49499999999999955
# Replay Memory size: 248
#
# ____________________________________________________________________________________________
# Episode 103 Done!
# Episode reward: -389.92092296142175
# Epsilon: 0.48999999999999955
# Replay Memory size: 305
#
# ____________________________________________________________________________________________
# Episode 104 Done!
# Episode reward: -251.5290039756339
# Epsilon: 0.48499999999999954
# Replay Memory size: 242
#
# ____________________________________________________________________________________________
# Episode 105 Done!
# Episode reward: -535.6854249492401
# Epsilon: 0.47999999999999954
# Replay Memory size: 346
#
# ____________________________________________________________________________________________
# Episode 106 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.47499999999999953
# Replay Memory size: 386
#
# ____________________________________________________________________________________________
# Episode 107 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.46999999999999953
# Replay Memory size: 394
#
# ____________________________________________________________________________________________
# Episode 108 Done!
# Episode reward: -146.87720036002506
# Epsilon: 0.4649999999999995
# Replay Memory size: 326
#
# ____________________________________________________________________________________________
# Episode 109 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.4599999999999995
# Replay Memory size: 334
#
# ____________________________________________________________________________________________
# Episode 110 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.4549999999999995
# Replay Memory size: 310
#
# ____________________________________________________________________________________________
# Episode 111 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.4499999999999995
# Replay Memory size: 382
#
# ____________________________________________________________________________________________
# Episode 112 Done!
# Episode reward: -467.8031739553309
# Epsilon: 0.4449999999999995
# Replay Memory size: 399
#
# ____________________________________________________________________________________________
# Episode 113 Done!
# Episode reward: -525.6854249492401
# Epsilon: 0.4399999999999995
# Replay Memory size: 343
#
# ____________________________________________________________________________________________
# Episode 114 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.4349999999999995
# Replay Memory size: 351
#
# ____________________________________________________________________________________________
# Episode 115 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.4299999999999995
# Replay Memory size: 295
#
# ____________________________________________________________________________________________
# Episode 116 Done!
# Episode reward: -545.6854249492402
# Epsilon: 0.4249999999999995
# Replay Memory size: 431
#
# ____________________________________________________________________________________________
# Episode 117 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.4199999999999995
# Replay Memory size: 375
#
# ____________________________________________________________________________________________
# Episode 118 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.4149999999999995
# Replay Memory size: 319
#
# ____________________________________________________________________________________________
# Episode 119 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.4099999999999995
# Replay Memory size: 359
#
# ____________________________________________________________________________________________
# Episode 120 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.40499999999999947
# Replay Memory size: 335
#
# ____________________________________________________________________________________________
# Episode 121 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.39999999999999947
# Replay Memory size: 375
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode120
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 122 Done!
# Episode reward: -535.6854249492399
# Epsilon: 0.39499999999999946
# Replay Memory size: 383
#
# ____________________________________________________________________________________________
# Episode 123 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.38999999999999946
# Replay Memory size: 391
#
# ____________________________________________________________________________________________
# Episode 124 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.38499999999999945
# Replay Memory size: 239
#
# ____________________________________________________________________________________________
# Episode 125 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.37999999999999945
# Replay Memory size: 407
#
# ____________________________________________________________________________________________
# Episode 126 Done!
# Episode reward: -545.6854249492402
# Epsilon: 0.37499999999999944
# Replay Memory size: 351
#
# ____________________________________________________________________________________________
# Episode 127 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.36999999999999944
# Replay Memory size: 263
#
# ____________________________________________________________________________________________
# Episode 128 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.36499999999999944
# Replay Memory size: 239
#
# ____________________________________________________________________________________________
# Episode 129 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.35999999999999943
# Replay Memory size: 279
#
# ____________________________________________________________________________________________
# Episode 130 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.3549999999999994
# Replay Memory size: 287
#
# ____________________________________________________________________________________________
# Episode 131 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.3499999999999994
# Replay Memory size: 231
#
# ____________________________________________________________________________________________
# Episode 132 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.3449999999999994
# Replay Memory size: 239
#
# ____________________________________________________________________________________________
# Episode 133 Done!
# Episode reward: -525.68542494924
# Epsilon: 0.3399999999999994
# Replay Memory size: 215
#
# ____________________________________________________________________________________________
# Episode 134 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.3349999999999994
# Replay Memory size: 255
#
# ____________________________________________________________________________________________
# Episode 135 Done!
# Episode reward: -545.68542494924
# Epsilon: 0.3299999999999994
# Replay Memory size: 231
#
# ____________________________________________________________________________________________
# Episode 136 Done!
# Episode reward: -285.4701294725885
# Epsilon: 0.3249999999999994
# Replay Memory size: 244
#
# ____________________________________________________________________________________________
# Episode 137 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.3199999999999994
# Replay Memory size: 220
#
# ____________________________________________________________________________________________
# Episode 138 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.3149999999999994
# Replay Memory size: 100
#
# ____________________________________________________________________________________________
# Episode 139 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.3099999999999994
# Replay Memory size: 140
#
# ____________________________________________________________________________________________
# Episode 140 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.3049999999999994
# Replay Memory size: 276
#
# ____________________________________________________________________________________________
# Episode 141 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.2999999999999994
# Replay Memory size: 252
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode140
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 142 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.2949999999999994
# Replay Memory size: 292
#
# ____________________________________________________________________________________________
# Episode 143 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.28999999999999937
# Replay Memory size: 396
#
# ____________________________________________________________________________________________
# Episode 144 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.28499999999999936
# Replay Memory size: 372
#
# ____________________________________________________________________________________________
# Episode 145 Done!
# Episode reward: -545.68542494924
# Epsilon: 0.27999999999999936
# Replay Memory size: 348
#
# ____________________________________________________________________________________________
# Episode 146 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.27499999999999936
# Replay Memory size: 260
#
# ____________________________________________________________________________________________
# Episode 147 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.26999999999999935
# Replay Memory size: 332
#
# ____________________________________________________________________________________________
# Episode 148 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.26499999999999935
# Replay Memory size: 308
#
# ____________________________________________________________________________________________
# Episode 149 Done!
# Episode reward: -535.6854249492399
# Epsilon: 0.25999999999999934
# Replay Memory size: 380
#
# ____________________________________________________________________________________________
# Episode 150 Done!
# Episode reward: -525.68542494924
# Epsilon: 0.25499999999999934
# Replay Memory size: 388
#
# ____________________________________________________________________________________________
# Episode 151 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.24999999999999933
# Replay Memory size: 396
#
# ____________________________________________________________________________________________
# Episode 152 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.24499999999999933
# Replay Memory size: 308
#
# ____________________________________________________________________________________________
# Episode 153 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.23999999999999932
# Replay Memory size: 380
#
# ____________________________________________________________________________________________
# Episode 154 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.23499999999999932
# Replay Memory size: 324
#
# ____________________________________________________________________________________________
# Episode 155 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.22999999999999932
# Replay Memory size: 236
#
# ____________________________________________________________________________________________
# Episode 156 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.2249999999999993
# Replay Memory size: 180
#
# ____________________________________________________________________________________________
# Episode 157 Done!
# Episode reward: -535.68542494924
# Epsilon: 0.2199999999999993
# Replay Memory size: 220
#
# ____________________________________________________________________________________________
# Episode 158 Done!
# Episode reward: -545.6854249492401
# Epsilon: 0.2149999999999993
# Replay Memory size: 228
#
# ____________________________________________________________________________________________
# Episode 159 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.2099999999999993
# Replay Memory size: 236
#
# ____________________________________________________________________________________________
# Episode 160 Done!
# Episode reward: -535.6854249492399
# Epsilon: 0.2049999999999993
# Replay Memory size: 308
#
# ____________________________________________________________________________________________
# Episode 161 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.1999999999999993
# Replay Memory size: 348
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode160
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 162 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.19499999999999929
# Replay Memory size: 388
#
# ____________________________________________________________________________________________
# Episode 163 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.18999999999999928
# Replay Memory size: 428
#
# ____________________________________________________________________________________________
# Episode 164 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.18499999999999928
# Replay Memory size: 372
#
# ____________________________________________________________________________________________
# Episode 165 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.17999999999999927
# Replay Memory size: 220
#
# ____________________________________________________________________________________________
# Episode 166 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.17499999999999927
# Replay Memory size: 228
#
# ____________________________________________________________________________________________
# Episode 167 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.16999999999999926
# Replay Memory size: 204
#
# ____________________________________________________________________________________________
# Episode 168 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.16499999999999926
# Replay Memory size: 212
#
# ____________________________________________________________________________________________
# Episode 169 Done!
# Episode reward: -545.68542494924
# Epsilon: 0.15999999999999925
# Replay Memory size: 188
#
# ____________________________________________________________________________________________
# Episode 170 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.15499999999999925
# Replay Memory size: 228
#
# ____________________________________________________________________________________________
# Episode 171 Done!
# Episode reward: -545.68542494924
# Epsilon: 0.14999999999999925
# Replay Memory size: 300
#
# ____________________________________________________________________________________________
# Episode 172 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.14499999999999924
# Replay Memory size: 372
#
# ____________________________________________________________________________________________
# Episode 173 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.13999999999999924
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 174 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.13499999999999923
# Replay Memory size: 260
#
# ____________________________________________________________________________________________
# Episode 175 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.12999999999999923
# Replay Memory size: 332
#
# ____________________________________________________________________________________________
# Episode 176 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.12499999999999922
# Replay Memory size: 340
#
# ____________________________________________________________________________________________
# Episode 177 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.11999999999999922
# Replay Memory size: 380
#
# ____________________________________________________________________________________________
# Episode 178 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.11499999999999921
# Replay Memory size: 388
#
# ____________________________________________________________________________________________
# Episode 179 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.10999999999999921
# Replay Memory size: 396
#
# ____________________________________________________________________________________________
# Episode 180 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.1049999999999992
# Replay Memory size: 340
#
# ____________________________________________________________________________________________
# Episode 181 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.0999999999999992
# Replay Memory size: 284
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode180
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 182 Done!
# Episode reward: -545.6854249492402
# Epsilon: 0.0949999999999992
# Replay Memory size: 388
#
# ____________________________________________________________________________________________
# Episode 183 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.08999999999999919
# Replay Memory size: 300
#
# ____________________________________________________________________________________________
# Episode 184 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.08499999999999919
# Replay Memory size: 308
#
# ____________________________________________________________________________________________
# Episode 185 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.07999999999999918
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 186 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.07499999999999918
# Replay Memory size: 324
#
# ____________________________________________________________________________________________
# Episode 187 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.06999999999999917
# Replay Memory size: 428
#
# ____________________________________________________________________________________________
# Episode 188 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.06499999999999917
# Replay Memory size: 404
#
# ____________________________________________________________________________________________
# Episode 189 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.05999999999999917
# Replay Memory size: 252
#
# ____________________________________________________________________________________________
# Episode 190 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.054999999999999175
# Replay Memory size: 228
#
# ____________________________________________________________________________________________
# Episode 191 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.04999999999999918
# Replay Memory size: 172
#
# ____________________________________________________________________________________________
# Episode 192 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.04499999999999918
# Replay Memory size: 244
#
# ____________________________________________________________________________________________
# Episode 193 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.03999999999999918
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 194 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.034999999999999185
# Replay Memory size: 292
#
# ____________________________________________________________________________________________
# Episode 195 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.029999999999999184
# Replay Memory size: 140
#
# ____________________________________________________________________________________________
# Episode 196 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.024999999999999183
# Replay Memory size: 276
#
# ____________________________________________________________________________________________
# Episode 197 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.01999999999999918
# Replay Memory size: 316
#
# ____________________________________________________________________________________________
# Episode 198 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01499999999999918
# Replay Memory size: 388
#
# ____________________________________________________________________________________________
# Episode 199 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.01
# Replay Memory size: 364
#
# ____________________________________________________________________________________________
# Episode 200 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 276
#
# ____________________________________________________________________________________________
# Episode 201 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 348
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/models/episode200
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/07Jun2020__190556416190/Reward.png
# ____________________________________________________________________________________________
# Episode 202 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 292
#
# ____________________________________________________________________________________________
# Episode 203 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 332
#
# ____________________________________________________________________________________________
# Episode 204 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.01
# Replay Memory size: 340
#
# ____________________________________________________________________________________________
# Episode 205 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.01
# Replay Memory size: 380
#
# ____________________________________________________________________________________________
# Episode 206 Done!
# Episode reward: -545.68542494924
# Epsilon: 0.01
# Replay Memory size: 420
#
# ____________________________________________________________________________________________
# Episode 207 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 332
#
# ____________________________________________________________________________________________
# Episode 208 Done!
# Episode reward: -555.6854249492401
# Epsilon: 0.01
# Replay Memory size: 340
#
# ____________________________________________________________________________________________
# Episode 209 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 348
#
# ____________________________________________________________________________________________
# Episode 210 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 292
#
# ____________________________________________________________________________________________
# Episode 211 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 268
#
# ____________________________________________________________________________________________
# Episode 212 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 276
#
# ____________________________________________________________________________________________
# Episode 213 Done!
# Episode reward: -555.6854249492402
# Epsilon: 0.01
# Replay Memory size: 316
#
# ____________________________________________________________________________________________
# Episode 214 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 260
#
# ____________________________________________________________________________________________
# Episode 215 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 236
#
# ____________________________________________________________________________________________
# Episode 216 Done!
# Episode reward: -565.6854249492402
# Epsilon: 0.01
# Replay Memory size: 308
#
# ____________________________________________________________________________________________
# ---------------------------------------------------------------------------
# _FallbackException                        Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_nn_ops.py in fused_batch_norm_v3(x, scale, offset, mean, variance, epsilon, exponential_avg_factor, data_format, is_training, name)
#    4246         epsilon, "exponential_avg_factor", exponential_avg_factor,
# -> 4247         "data_format", data_format, "is_training", is_training)
#    4248       _result = _FusedBatchNormV3Output._make(_result)
#
# _FallbackException: Expecting float value for attr exponential_avg_factor, got int
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f1205ca93d58> in <module>()
#       7 model.compile(optimizer=optimizer)
#       8
# ----> 9 model = train_dqn(model, optimizer, reward, **config)
#      10 t = time() - t
#
# /content/drive/My Drive/snakeAI/models/model_train.py in train_dqn(model, optimizer, reward, **kwargs)
#     192                 episode_images.append(state)
#     193
# --> 194             q = model(state.reshape((-1, *state.shape)))
#     195             direction = np.random.randint(4) if np.random.rand(1) < epsilon else np.argmax(q)
#     196             env.step({0: direction})
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     275       if not self.built:
#     276         self._init_graph_network(self.inputs, self.outputs, name=self.name)
# --> 277       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     278
#     279     outputs = inputs  # handle the corner case where self.layers is empty
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py in call(self, inputs, training, mask)
#     717     return self._run_internal_graph(
#     718         inputs, training=training, mask=mask,
# --> 719         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     720
#     721   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py in _run_internal_graph(self, inputs, training, mask, convert_kwargs_to_constants)
#     886
#     887           # Compute outputs.
# --> 888           output_tensors = layer(computed_tensors, **kwargs)
#     889
#     890           # Update tensor_dict.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py in call(self, inputs, training, mask)
#     717     return self._run_internal_graph(
#     718         inputs, training=training, mask=mask,
# --> 719         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     720
#     721   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py in _run_internal_graph(self, inputs, training, mask, convert_kwargs_to_constants)
#     886
#     887           # Compute outputs.
# --> 888           output_tensors = layer(computed_tensors, **kwargs)
#     889
#     890           # Update tensor_dict.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/normalization.py in call(self, inputs, training)
#     739
#     740     if self.fused:
# --> 741       outputs = self._fused_batch_norm(inputs, training=training)
#     742       if self.virtual_batch_size is not None:
#     743         # Currently never reaches here since fused_batch_norm does not support
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/normalization.py in _fused_batch_norm(self, inputs, training)
#     602
#     603     output, mean, variance = tf_utils.smart_cond(training, train_op,
# --> 604                                                  _fused_batch_norm_inference)
#     605     variance = _maybe_add_or_remove_bessels_correction(variance, remove=True)
#     606
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/tf_utils.py in smart_cond(pred, true_fn, false_fn, name)
#      63         pred, true_fn=true_fn, false_fn=false_fn, name=name)
#      64   return smart_module.smart_cond(
# ---> 65       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#      66
#      67
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      54       return true_fn()
#      55     else:
# ---> 56       return false_fn()
#      57   else:
#      58     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/normalization.py in _fused_batch_norm_inference()
#     591           epsilon=self.epsilon,
#     592           is_training=False,
# --> 593           data_format=self._data_format)
#     594
#     595     train_op = _fused_batch_norm_training
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py in fused_batch_norm(x, scale, offset, mean, variance, epsilon, data_format, is_training, name, exponential_avg_factor)
#    1542         data_format=data_format,
#    1543         is_training=is_training,
# -> 1544         name=name)
#    1545     return y, running_mean, running_var
#    1546
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_nn_ops.py in fused_batch_norm_v3(x, scale, offset, mean, variance, epsilon, exponential_avg_factor, data_format, is_training, name)
#    4254             exponential_avg_factor=exponential_avg_factor,
#    4255             data_format=data_format, is_training=is_training, name=name,
# -> 4256             ctx=_ctx)
#    4257       except _core._SymbolicException:
#    4258         pass  # Add nodes to the TensorFlow graph.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_nn_ops.py in fused_batch_norm_v3_eager_fallback(x, scale, offset, mean, variance, epsilon, exponential_avg_factor, data_format, is_training, name, ctx)
#    4315   data_format, "is_training", is_training)
#    4316   _result = _execute.execute(b"FusedBatchNormV3", 6, inputs=_inputs_flat,
# -> 4317                              attrs=_attrs, ctx=ctx, name=name)
#    4318   if _execute.must_record_gradient():
#    4319     _execute.record_gradient(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
assert False
env = SnakeMaze(20, 20, 1, with_boundaries=False)
env.reset()
imgs = []
while env.num_active_agents:
    imgs.append(env.snake_matrices[0])
    # state = resize_image(env.snake_matrices[0], IMAGE_SIZE)
    direction = np.argmax(model(np.array([state])))
    env.step({0: direction})

# %%
generate_animation(imgs)
