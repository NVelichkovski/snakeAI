# %%
import sys
sys.path.append("/content/drive/My Drive/snakeAI")

from collections import namedtuple

Experience = namedtuple('Experience', ('state', 'direction', 'next_state', 'reward'))

import tensorflow as tf
import tensorflow.keras as k

from Snake.environment import SnakeMaze
from Snake.variables import Status, Cell
from models.replay_memory import ReplayMemory
from models.model_train import train_dqn
from Snake.utils import euclidean_distance

from datetime import datetime
import numpy as np
import cv2
import os
from time import time

# %% [markdown]
# # ResNet50

# %%
def ResNet50(input_shape, num_not_trainable_blocks=4):
  base_model = k.applications.ResNet50(include_top=False, input_shape=input_shape)
  base_model.trainable = False

  for l in base_model.layers:
    if l.name.split("_")[0] == f"conv{num_not_trainable_blocks+1}":
      break
    l.trainable = True

  model = k.Sequential([
      base_model,
      k.layers.Flatten(),
      k.layers.Dense(4096, activation='relu'),
      k.layers.Dense(2048, activation='relu'),
      k.layers.Dense(1024, activation='relu'),
      k.layers.Dense(512, activation='relu'),
      k.layers.Dense(4, activation='linear'),
  ])

  model.build(input_shape=input_shape)
  return model

# %% [markdown]
# ### Configuration

# %%
"""
            Training model

            :param model: tf.keras.Model
                An instance ovr the keras.Model
            :param reward: function
                A function that returns the reward of the current state

                Args:
                    ::param snake: Snake
                    ::param env: SnakeMaze
                    ::param direction: Direction

                Returns:
                    int: The current reward

            :param optimizer: tf.keras.Optimizer
                The optimizer used to train the model

            :param kwargs:
                save_images (bool): False
                    If true images are saved on the eval episode

                save_videos (bool): False
                    If true videos are saved on the eval episode

                save_models (bool): False
                    If true models are saved on the eval episode

                save_graphs (bool): False
                    If true graphs are saved on the eval episode

                evaluate_each (int): 50
                    Number of episodes between two evaluations

                num_rolling_avg_sample (int): 50
                    Number of episodes that are used for the rolling average

                max_steps_per_episode (int): 200
                    Max number of steps in each episode

                num_episodes (int, None): None
                    Number of episodes to train, if None runs forever

                gamma (float): .8
                    The discount factor

                epsilon (float): 1.
                    The exploration/exploitation rate

                epsilon_decay (float): 0.0005
                    The decay of the exploration/exploitation rate

                min_epsilon (float): 0.01
                    The epsilon convergence

                memory_size (int): 100000
                    Capacity of the reply memory, if less then 50 Replay Memory will not be used

                boundaries (bool): True
                    Include boundaries in the maze

                maze_width (int): 10
                    The width of the maze

                maze_height (int, None): None
                    The height of the maze, if not specified the maze is squared

                max_snakes (int): 1
                    The max number of snakes in the environment

                path_to_weights (str): None
                    Path to saved weights for the model

                image_size (tuple[int, int]): (112, 112)
                    The size of the image used as input in the model

                verbose (bool): True
                    Print info about the training

                training_dir (str): './'
                    Path to the directory for training
            """
# Out:
# "\n            Training model\n\n            :param model: tf.keras.Model\n                An instance ovr the keras.Model\n            :param reward: function\n                A function that returns the reward of the current state\n\n                Args:\n                    ::param snake: Snake\n                    ::param env: SnakeMaze\n                    ::param direction: Direction\n\n                Returns:\n                    int: The current reward\n\n            :param optimizer: tf.keras.Optimizer\n                The optimizer used to train the model\n\n            :param kwargs:\n                save_images (bool): False\n                    If true images are saved on the eval episode\n\n                save_videos (bool): False\n                    If true videos are saved on the eval episode\n\n                save_models (bool): False\n                    If true models are saved on the eval episode\n\n                save_graphs (bool): False\n                    If true graphs are saved on the eval episode\n\n                evaluate_each (int): 50\n                    Number of episodes between two evaluations\n\n                num_rolling_avg_sample (int): 50\n                    Number of episodes that are used for the rolling average\n\n                max_steps_per_episode (int): 200\n                    Max number of steps in each episode\n\n                num_episodes (int, None): None\n                    Number of episodes to train, if None runs forever\n\n                gamma (float): .8\n                    The discount factor\n\n                epsilon (float): 1.\n                    The exploration/exploitation rate\n\n                epsilon_decay (float): 0.0005\n                    The decay of the exploration/exploitation rate\n\n                min_epsilon (float): 0.01\n                    The epsilon convergence\n\n                memory_size (int): 100000\n                    Capacity of the reply memory, if less then 50 Replay Memory will not be used\n\n                boundaries (bool): True\n                    Include boundaries in the maze\n\n                maze_width (int): 10\n                    The width of the maze\n\n                maze_height (int, None): None\n                    The height of the maze, if not specified the maze is squared\n\n                max_snakes (int): 1\n                    The max number of snakes in the environment\n\n                path_to_weights (str): None\n                    Path to saved weights for the model\n\n                image_size (tuple[int, int]): (112, 112)\n                    The size of the image used as input in the model\n\n                verbose (bool): True\n                    Print info about the training\n\n                training_dir (str): './'\n                    Path to the directory for training\n            "

# %%
NUM_NOT_TRAINABLE_BLOCKS = 4

IMAGE_SIZE = (64, 64)
IMAGE_SHAPE = (*IMAGE_SIZE, 3)

learning_rate = 1e-5

config = {
  "num_rolling_avg_sample": 10,
  "evaluate_each": 20,
  "save_models": True,
  "save_graphs": True,
  "gamma": .99,
  "epsilon_decay": 0.0005,
  "boundaries": False,
  "maze_width": 10,
  "image_size": IMAGE_SIZE,
  "batch_size": 128,
  "comment": f"""
  Architecture: ResNet50
  Weights: imagenet, {NUM_NOT_TRAINABLE_BLOCKS} non trainable blocks
  Optimizer: Adam ( with amsgrad )
  Hyperparameters:
    lr = {learning_rate}
  Reward:
      if snake.status == Status.DEAD:
        return 0
    else:
        r = 0
        r += 1000 if snake.steps_without_food == 1 else 0
        return r

  Reward only for eating food
  """
}

# %% [markdown]
# ### Training

# %%
envv = SnakeMaze(10, 10, 1)
envv.reset()

# %%
def reward(snake, env: SnakeMaze, direction):
    if snake.status == Status.DEAD:
        return -1000
        return 0
    else:
        r = 0
        r -= euclidean_distance(envv.snakes[0].body[0], list(envv.food)[0])
        r += 50 if snake.steps_without_food == 1 else 0
        return r

# %%
t = time()
config["training_dir"] = os.path.join(*['drive', 'My Drive', 'snakeAI', 'trainings', 'transfer_learningDQN', "ResNet50", datetime.now().strftime('%d%h%Y__%H%M%S%f')])
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, amsgrad=True)

model = ResNet50(input_shape=IMAGE_SHAPE, num_not_trainable_blocks=NUM_NOT_TRAINABLE_BLOCKS)
model.build(input_shape=(None, *IMAGE_SHAPE))
model.compile(optimizer=optimizer)

model = train_dqn(model, optimizer, reward, **config)
t = time() - t
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step
# ____________________________________________________________________________________________
# Episode 1 Done!
# Episode reward: -500.0
# Epsilon: 1.0
# Replay Memory size: 136
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 2 Done!
# Episode reward: -550.0
# Epsilon: 0.9995
# Replay Memory size: 176
#
# ____________________________________________________________________________________________
# Episode 3 Done!
# Episode reward: -550.0
# Epsilon: 0.9990000000000001
# Replay Memory size: 280
#
# ____________________________________________________________________________________________
# Episode 4 Done!
# Episode reward: -500.0
# Epsilon: 0.9985000000000002
# Replay Memory size: 320
#
# ____________________________________________________________________________________________
# Episode 5 Done!
# Episode reward: -1144.0
# Epsilon: 0.9980000000000002
# Replay Memory size: 355
#
# ____________________________________________________________________________________________
# Episode 6 Done!
# Episode reward: -550.0
# Epsilon: 0.9975000000000003
# Replay Memory size: 331
#
# ____________________________________________________________________________________________
# Episode 7 Done!
# Episode reward: -1272.0
# Epsilon: 0.9970000000000003
# Replay Memory size: 264
#
# ____________________________________________________________________________________________
# Episode 8 Done!
# Episode reward: -1359.0
# Epsilon: 0.9965000000000004
# Replay Memory size: 322
#
# ____________________________________________________________________________________________
# Episode 9 Done!
# Episode reward: -450.0
# Epsilon: 0.9960000000000004
# Replay Memory size: 330
#
# ____________________________________________________________________________________________
# Episode 10 Done!
# Episode reward: -550.0
# Epsilon: 0.9955000000000005
# Replay Memory size: 242
#
# ____________________________________________________________________________________________
# Episode 11 Done!
# Episode reward: -1449.0
# Epsilon: 0.9950000000000006
# Replay Memory size: 330
#
# ____________________________________________________________________________________________
# Episode 12 Done!
# Episode reward: -550.0
# Epsilon: 0.9945000000000006
# Replay Memory size: 306
#
# ____________________________________________________________________________________________
# Episode 13 Done!
# Episode reward: -1473.0
# Epsilon: 0.9940000000000007
# Replay Memory size: 242
#
# ____________________________________________________________________________________________
# Episode 14 Done!
# Episode reward: -550.0
# Epsilon: 0.9935000000000007
# Replay Memory size: 314
#
# ____________________________________________________________________________________________
# Episode 15 Done!
# Episode reward: -600.0
# Epsilon: 0.9930000000000008
# Replay Memory size: 226
#
# ____________________________________________________________________________________________
# Episode 16 Done!
# Episode reward: -1249.0
# Epsilon: 0.9925000000000008
# Replay Memory size: 264
#
# ____________________________________________________________________________________________
# Episode 17 Done!
# Episode reward: -1101.0
# Epsilon: 0.9920000000000009
# Replay Memory size: 300
#
# ____________________________________________________________________________________________
# Episode 18 Done!
# Episode reward: -450.0
# Epsilon: 0.9915000000000009
# Replay Memory size: 340
#
# ____________________________________________________________________________________________
# Episode 19 Done!
# Episode reward: -550.0
# Epsilon: 0.991000000000001
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 20 Done!
# Episode reward: -550.0
# Epsilon: 0.990500000000001
# Replay Memory size: 324
#
# ____________________________________________________________________________________________
# Episode 21 Done!
# Episode reward: -1106.0
# Epsilon: 0.9900000000000011
# Replay Memory size: 363
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 22 Done!
# Episode reward: -1395.0
# Epsilon: 0.9895000000000012
# Replay Memory size: 241
#
# ____________________________________________________________________________________________
# Episode 23 Done!
# Episode reward: -1320.0
# Epsilon: 0.9890000000000012
# Replay Memory size: 318
#
# ____________________________________________________________________________________________
# Episode 24 Done!
# Episode reward: -1216.0
# Epsilon: 0.9885000000000013
# Replay Memory size: 313
#
# ____________________________________________________________________________________________
# Episode 25 Done!
# Episode reward: -1119.0
# Epsilon: 0.9880000000000013
# Replay Memory size: 323
#
# ____________________________________________________________________________________________
# Episode 26 Done!
# Episode reward: -1059.0
# Epsilon: 0.9875000000000014
# Replay Memory size: 345
#
# ____________________________________________________________________________________________
# Episode 27 Done!
# Episode reward: -1488.0
# Epsilon: 0.9870000000000014
# Replay Memory size: 350
#
# ____________________________________________________________________________________________
# Episode 28 Done!
# Episode reward: -1257.0
# Epsilon: 0.9865000000000015
# Replay Memory size: 278
#
# ____________________________________________________________________________________________
# Episode 29 Done!
# Episode reward: -500.0
# Epsilon: 0.9860000000000015
# Replay Memory size: 382
#
# ____________________________________________________________________________________________
# Episode 30 Done!
# Episode reward: -1135.0
# Epsilon: 0.9855000000000016
# Replay Memory size: 414
#
# ____________________________________________________________________________________________
# Episode 31 Done!
# Episode reward: -450.0
# Epsilon: 0.9850000000000017
# Replay Memory size: 294
#
# ____________________________________________________________________________________________
# Episode 32 Done!
# Episode reward: -1449.0
# Epsilon: 0.9845000000000017
# Replay Memory size: 350
#
# ____________________________________________________________________________________________
# Episode 33 Done!
# Episode reward: -500.0
# Epsilon: 0.9840000000000018
# Replay Memory size: 390
#
# ____________________________________________________________________________________________
# Episode 34 Done!
# Episode reward: -500.0
# Epsilon: 0.9835000000000018
# Replay Memory size: 334
#
# ____________________________________________________________________________________________
# Episode 35 Done!
# Episode reward: -1146.0
# Epsilon: 0.9830000000000019
# Replay Memory size: 321
#
# ____________________________________________________________________________________________
# Episode 36 Done!
# Episode reward: -1407.0
# Epsilon: 0.9825000000000019
# Replay Memory size: 299
#
# ____________________________________________________________________________________________
# Episode 37 Done!
# Episode reward: -550.0
# Epsilon: 0.982000000000002
# Replay Memory size: 307
#
# ____________________________________________________________________________________________
# Episode 38 Done!
# Episode reward: -600.0
# Epsilon: 0.981500000000002
# Replay Memory size: 379
#
# ____________________________________________________________________________________________
# Episode 39 Done!
# Episode reward: -600.0
# Epsilon: 0.9810000000000021
# Replay Memory size: 483
#
# ____________________________________________________________________________________________
# Episode 40 Done!
# Episode reward: -934.0
# Epsilon: 0.9805000000000021
# Replay Memory size: 512
#
# ____________________________________________________________________________________________
# Episode 41 Done!
# Episode reward: -1176.0
# Epsilon: 0.9800000000000022
# Replay Memory size: 509
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 42 Done!
# Episode reward: -550.0
# Epsilon: 0.9795000000000023
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 43 Done!
# Episode reward: -600.0
# Epsilon: 0.9790000000000023
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 44 Done!
# Episode reward: -550.0
# Epsilon: 0.9785000000000024
# Replay Memory size: 277
#
# ____________________________________________________________________________________________
# Episode 45 Done!
# Episode reward: -550.0
# Epsilon: 0.9780000000000024
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 46 Done!
# Episode reward: -550.0
# Epsilon: 0.9775000000000025
# Replay Memory size: 293
#
# ____________________________________________________________________________________________
# Episode 47 Done!
# Episode reward: -1350.0
# Epsilon: 0.9770000000000025
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 48 Done!
# Episode reward: -600.0
# Epsilon: 0.9765000000000026
# Replay Memory size: 388
#
# ____________________________________________________________________________________________
# Episode 49 Done!
# Episode reward: -550.0
# Epsilon: 0.9760000000000026
# Replay Memory size: 364
#
# ____________________________________________________________________________________________
# Episode 50 Done!
# Episode reward: -550.0
# Epsilon: 0.9755000000000027
# Replay Memory size: 276
#
# ____________________________________________________________________________________________
# Episode 51 Done!
# Episode reward: -500.0
# Epsilon: 0.9750000000000028
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 52 Done!
# Episode reward: -1311.0
# Epsilon: 0.9745000000000028
# Replay Memory size: 198
#
# ____________________________________________________________________________________________
# Episode 53 Done!
# Episode reward: -500.0
# Epsilon: 0.9740000000000029
# Replay Memory size: 238
#
# ____________________________________________________________________________________________
# Episode 54 Done!
# Episode reward: -1293.0
# Epsilon: 0.9735000000000029
# Replay Memory size: 338
#
# ____________________________________________________________________________________________
# Episode 55 Done!
# Episode reward: -550.0
# Epsilon: 0.973000000000003
# Replay Memory size: 314
#
# ____________________________________________________________________________________________
# Episode 56 Done!
# Episode reward: -550.0
# Epsilon: 0.972500000000003
# Replay Memory size: 322
#
# ____________________________________________________________________________________________
# Episode 57 Done!
# Episode reward: -500.0
# Epsilon: 0.9720000000000031
# Replay Memory size: 266
#
# ____________________________________________________________________________________________
# Episode 58 Done!
# Episode reward: -500.0
# Epsilon: 0.9715000000000031
# Replay Memory size: 402
#
# ____________________________________________________________________________________________
# Episode 59 Done!
# Episode reward: -1098.0
# Epsilon: 0.9710000000000032
# Replay Memory size: 437
#
# ____________________________________________________________________________________________
# Episode 60 Done!
# Episode reward: -550.0
# Epsilon: 0.9705000000000032
# Replay Memory size: 221
#
# ____________________________________________________________________________________________
# Episode 61 Done!
# Episode reward: -600.0
# Epsilon: 0.9700000000000033
# Replay Memory size: 197
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 62 Done!
# Episode reward: -600.0
# Epsilon: 0.9695000000000034
# Replay Memory size: 237
#
# ____________________________________________________________________________________________
# Episode 63 Done!
# Episode reward: -1365.0
# Epsilon: 0.9690000000000034
# Replay Memory size: 201
#
# ____________________________________________________________________________________________
# Episode 64 Done!
# Episode reward: -550.0
# Epsilon: 0.9685000000000035
# Replay Memory size: 177
#
# ____________________________________________________________________________________________
# Episode 65 Done!
# Episode reward: -550.0
# Epsilon: 0.9680000000000035
# Replay Memory size: 249
#
# ____________________________________________________________________________________________
# Episode 66 Done!
# Episode reward: -1152.0
# Epsilon: 0.9675000000000036
# Replay Memory size: 206
#
# ____________________________________________________________________________________________
# Episode 67 Done!
# Episode reward: -1275.0
# Epsilon: 0.9670000000000036
# Replay Memory size: 204
#
# ____________________________________________________________________________________________
# Episode 68 Done!
# Episode reward: -1251.0
# Epsilon: 0.9665000000000037
# Replay Memory size: 258
#
# ____________________________________________________________________________________________
# Episode 69 Done!
# Episode reward: -1023.0
# Epsilon: 0.9660000000000037
# Replay Memory size: 300
#
# ____________________________________________________________________________________________
# Episode 70 Done!
# Episode reward: -999.0
# Epsilon: 0.9655000000000038
# Replay Memory size: 270
#
# ____________________________________________________________________________________________
# Episode 71 Done!
# Episode reward: -1288.0
# Epsilon: 0.9650000000000039
# Replay Memory size: 289
#
# ____________________________________________________________________________________________
# Episode 72 Done!
# Episode reward: -1125.0
# Epsilon: 0.9645000000000039
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 73 Done!
# Episode reward: -1017.0
# Epsilon: 0.964000000000004
# Replay Memory size: 213
#
# ____________________________________________________________________________________________
# Episode 74 Done!
# Episode reward: -1386.0
# Epsilon: 0.963500000000004
# Replay Memory size: 280
#
# ____________________________________________________________________________________________
# Episode 75 Done!
# Episode reward: -500.0
# Epsilon: 0.9630000000000041
# Replay Memory size: 288
#
# ____________________________________________________________________________________________
# Episode 76 Done!
# Episode reward: -550.0
# Epsilon: 0.9625000000000041
# Replay Memory size: 328
#
# ____________________________________________________________________________________________
# Episode 77 Done!
# Episode reward: -550.0
# Epsilon: 0.9620000000000042
# Replay Memory size: 272
#
# ____________________________________________________________________________________________
# Episode 78 Done!
# Episode reward: -600.0
# Epsilon: 0.9615000000000042
# Replay Memory size: 248
#
# ____________________________________________________________________________________________
# Episode 79 Done!
# Episode reward: -550.0
# Epsilon: 0.9610000000000043
# Replay Memory size: 288
#
# ____________________________________________________________________________________________
# Episode 80 Done!
# Episode reward: -500.0
# Epsilon: 0.9605000000000044
# Replay Memory size: 328
#
# ____________________________________________________________________________________________
# Episode 81 Done!
# Episode reward: -1341.0
# Epsilon: 0.9600000000000044
# Replay Memory size: 380
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 82 Done!
# Episode reward: -500.0
# Epsilon: 0.9595000000000045
# Replay Memory size: 420
#
# ____________________________________________________________________________________________
# Episode 83 Done!
# Episode reward: -1134.0
# Epsilon: 0.9590000000000045
# Replay Memory size: 339
#
# ____________________________________________________________________________________________
# Episode 84 Done!
# Episode reward: -550.0
# Epsilon: 0.9585000000000046
# Replay Memory size: 411
#
# ____________________________________________________________________________________________
# Episode 85 Done!
# Episode reward: -550.0
# Epsilon: 0.9580000000000046
# Replay Memory size: 323
#
# ____________________________________________________________________________________________
# Episode 86 Done!
# Episode reward: -1367.0
# Epsilon: 0.9575000000000047
# Replay Memory size: 225
#
# ____________________________________________________________________________________________
# Episode 87 Done!
# Episode reward: -1290.0
# Epsilon: 0.9570000000000047
# Replay Memory size: 324
#
# ____________________________________________________________________________________________
# Episode 88 Done!
# Episode reward: -550.0
# Epsilon: 0.9565000000000048
# Replay Memory size: 268
#
# ____________________________________________________________________________________________
# Episode 89 Done!
# Episode reward: -1048.0
# Epsilon: 0.9560000000000048
# Replay Memory size: 303
#
# ____________________________________________________________________________________________
# Episode 90 Done!
# Episode reward: -450.0
# Epsilon: 0.9555000000000049
# Replay Memory size: 343
#
# ____________________________________________________________________________________________
# Episode 91 Done!
# Episode reward: -550.0
# Epsilon: 0.955000000000005
# Replay Memory size: 191
#
# ____________________________________________________________________________________________
# Episode 92 Done!
# Episode reward: -1380.0
# Epsilon: 0.954500000000005
# Replay Memory size: 224
#
# ____________________________________________________________________________________________
# Episode 93 Done!
# Episode reward: -550.0
# Epsilon: 0.9540000000000051
# Replay Memory size: 264
#
# ____________________________________________________________________________________________
# Episode 94 Done!
# Episode reward: -1141.0
# Epsilon: 0.9535000000000051
# Replay Memory size: 330
#
# ____________________________________________________________________________________________
# Episode 95 Done!
# Episode reward: -1216.0
# Epsilon: 0.9530000000000052
# Replay Memory size: 357
#
# ____________________________________________________________________________________________
# Episode 96 Done!
# Episode reward: -550.0
# Epsilon: 0.9525000000000052
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 97 Done!
# Episode reward: -1401.0
# Epsilon: 0.9520000000000053
# Replay Memory size: 245
#
# ____________________________________________________________________________________________
# Episode 98 Done!
# Episode reward: -1143.0
# Epsilon: 0.9515000000000053
# Replay Memory size: 295
#
# ____________________________________________________________________________________________
# Episode 99 Done!
# Episode reward: -1371.0
# Epsilon: 0.9510000000000054
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 100 Done!
# Episode reward: -550.0
# Epsilon: 0.9505000000000055
# Replay Memory size: 237
#
# ____________________________________________________________________________________________
# Episode 101 Done!
# Episode reward: -1290.0
# Epsilon: 0.9500000000000055
# Replay Memory size: 272
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 102 Done!
# Episode reward: -1140.0
# Epsilon: 0.9495000000000056
# Replay Memory size: 225
#
# ____________________________________________________________________________________________
# Episode 103 Done!
# Episode reward: -1398.0
# Epsilon: 0.9490000000000056
# Replay Memory size: 360
#
# ____________________________________________________________________________________________
# Episode 104 Done!
# Episode reward: -500.0
# Epsilon: 0.9485000000000057
# Replay Memory size: 240
#
# ____________________________________________________________________________________________
# Episode 105 Done!
# Episode reward: -550.0
# Epsilon: 0.9480000000000057
# Replay Memory size: 280
#
# ____________________________________________________________________________________________
# Episode 106 Done!
# Episode reward: -1401.0
# Epsilon: 0.9475000000000058
# Replay Memory size: 192
#
# ____________________________________________________________________________________________
# Episode 107 Done!
# Episode reward: -550.0
# Epsilon: 0.9470000000000058
# Replay Memory size: 232
#
# ____________________________________________________________________________________________
# Episode 108 Done!
# Episode reward: -600.0
# Epsilon: 0.9465000000000059
# Replay Memory size: 304
#
# ____________________________________________________________________________________________
# Episode 109 Done!
# Episode reward: -976.0
# Epsilon: 0.946000000000006
# Replay Memory size: 315
#
# ____________________________________________________________________________________________
# Episode 110 Done!
# Episode reward: -1155.0
# Epsilon: 0.945500000000006
# Replay Memory size: 369
#
# ____________________________________________________________________________________________
# Episode 111 Done!
# Episode reward: -500.0
# Epsilon: 0.9450000000000061
# Replay Memory size: 441
#
# ____________________________________________________________________________________________
# Episode 112 Done!
# Episode reward: -550.0
# Epsilon: 0.9445000000000061
# Replay Memory size: 321
#
# ____________________________________________________________________________________________
# Episode 113 Done!
# Episode reward: -1230.0
# Epsilon: 0.9440000000000062
# Replay Memory size: 336
#
# ____________________________________________________________________________________________
# Episode 114 Done!
# Episode reward: -1251.0
# Epsilon: 0.9435000000000062
# Replay Memory size: 326
#
# ____________________________________________________________________________________________
# Episode 115 Done!
# Episode reward: -1341.0
# Epsilon: 0.9430000000000063
# Replay Memory size: 314
#
# ____________________________________________________________________________________________
# Episode 116 Done!
# Episode reward: -550.0
# Epsilon: 0.9425000000000063
# Replay Memory size: 226
#
# ____________________________________________________________________________________________
# Episode 117 Done!
# Episode reward: -1062.0
# Epsilon: 0.9420000000000064
# Replay Memory size: 217
#
# ____________________________________________________________________________________________
# Episode 118 Done!
# Episode reward: -600.0
# Epsilon: 0.9415000000000064
# Replay Memory size: 257
#
# ____________________________________________________________________________________________
# Episode 119 Done!
# Episode reward: -600.0
# Epsilon: 0.9410000000000065
# Replay Memory size: 329
#
# ____________________________________________________________________________________________
# Episode 120 Done!
# Episode reward: -550.0
# Epsilon: 0.9405000000000066
# Replay Memory size: 337
#
# ____________________________________________________________________________________________
# Episode 121 Done!
# Episode reward: -550.0
# Epsilon: 0.9400000000000066
# Replay Memory size: 249
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 122 Done!
# Episode reward: -1056.0
# Epsilon: 0.9395000000000067
# Replay Memory size: 206
#
# ____________________________________________________________________________________________
# Episode 123 Done!
# Episode reward: -1168.0
# Epsilon: 0.9390000000000067
# Replay Memory size: 217
#
# ____________________________________________________________________________________________
# Episode 124 Done!
# Episode reward: -450.0
# Epsilon: 0.9385000000000068
# Replay Memory size: 353
#
# ____________________________________________________________________________________________
# Episode 125 Done!
# Episode reward: -1181.0
# Epsilon: 0.9380000000000068
# Replay Memory size: 449
#
# ____________________________________________________________________________________________
# Episode 126 Done!
# Episode reward: -600.0
# Epsilon: 0.9375000000000069
# Replay Memory size: 425
#
# ____________________________________________________________________________________________
# Episode 127 Done!
# Episode reward: -1153.0
# Epsilon: 0.9370000000000069
# Replay Memory size: 399
#
# ____________________________________________________________________________________________
# Episode 128 Done!
# Episode reward: -1410.0
# Epsilon: 0.936500000000007
# Replay Memory size: 314
#
# ____________________________________________________________________________________________
# Episode 129 Done!
# Episode reward: -500.0
# Epsilon: 0.936000000000007
# Replay Memory size: 258
#
# ____________________________________________________________________________________________
# Episode 130 Done!
# Episode reward: -450.0
# Epsilon: 0.9355000000000071
# Replay Memory size: 234
#
# ____________________________________________________________________________________________
# Episode 131 Done!
# Episode reward: -1444.0
# Epsilon: 0.9350000000000072
# Replay Memory size: 305
#
# ____________________________________________________________________________________________
# Episode 132 Done!
# Episode reward: -1379.0
# Epsilon: 0.9345000000000072
# Replay Memory size: 339
#
# ____________________________________________________________________________________________
# Episode 133 Done!
# Episode reward: -550.0
# Epsilon: 0.9340000000000073
# Replay Memory size: 315
#
# ____________________________________________________________________________________________
# Episode 134 Done!
# Episode reward: -1476.0
# Epsilon: 0.9335000000000073
# Replay Memory size: 252
#
# ____________________________________________________________________________________________
# Episode 135 Done!
# Episode reward: -600.0
# Epsilon: 0.9330000000000074
# Replay Memory size: 260
#
# ____________________________________________________________________________________________
# Episode 136 Done!
# Episode reward: -1398.0
# Epsilon: 0.9325000000000074
# Replay Memory size: 363
#
# ____________________________________________________________________________________________
# Episode 137 Done!
# Episode reward: -400.0
# Epsilon: 0.9320000000000075
# Replay Memory size: 243
#
# ____________________________________________________________________________________________
# Episode 138 Done!
# Episode reward: -550.0
# Epsilon: 0.9315000000000075
# Replay Memory size: 283
#
# ____________________________________________________________________________________________
# Episode 139 Done!
# Episode reward: -550.0
# Epsilon: 0.9310000000000076
# Replay Memory size: 259
#
# ____________________________________________________________________________________________
# Episode 140 Done!
# Episode reward: -1245.0
# Epsilon: 0.9305000000000077
# Replay Memory size: 279
#
# ____________________________________________________________________________________________
# Episode 141 Done!
# Episode reward: -1023.0
# Epsilon: 0.9300000000000077
# Replay Memory size: 289
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 142 Done!
# Episode reward: -1296.0
# Epsilon: 0.9295000000000078
# Replay Memory size: 408
#
# ____________________________________________________________________________________________
# Episode 143 Done!
# Episode reward: -1293.0
# Epsilon: 0.9290000000000078
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 144 Done!
# Episode reward: -600.0
# Epsilon: 0.9285000000000079
# Replay Memory size: 292
#
# ____________________________________________________________________________________________
# Episode 145 Done!
# Episode reward: -990.0
# Epsilon: 0.9280000000000079
# Replay Memory size: 323
#
# ____________________________________________________________________________________________
# Episode 146 Done!
# Episode reward: -550.0
# Epsilon: 0.927500000000008
# Replay Memory size: 427
#
# ____________________________________________________________________________________________
# Episode 147 Done!
# Episode reward: -500.0
# Epsilon: 0.927000000000008
# Replay Memory size: 371
#
# ____________________________________________________________________________________________
# Episode 148 Done!
# Episode reward: -450.0
# Epsilon: 0.9265000000000081
# Replay Memory size: 347
#
# ____________________________________________________________________________________________
# Episode 149 Done!
# Episode reward: -500.0
# Epsilon: 0.9260000000000081
# Replay Memory size: 323
#
# ____________________________________________________________________________________________
# Episode 150 Done!
# Episode reward: -550.0
# Epsilon: 0.9255000000000082
# Replay Memory size: 363
#
# ____________________________________________________________________________________________
# Episode 151 Done!
# Episode reward: -550.0
# Epsilon: 0.9250000000000083
# Replay Memory size: 435
#
# ____________________________________________________________________________________________
# Episode 152 Done!
# Episode reward: -1174.0
# Epsilon: 0.9245000000000083
# Replay Memory size: 448
#
# ____________________________________________________________________________________________
# Episode 153 Done!
# Episode reward: -1251.0
# Epsilon: 0.9240000000000084
# Replay Memory size: 406
#
# ____________________________________________________________________________________________
# Episode 154 Done!
# Episode reward: -550.0
# Epsilon: 0.9235000000000084
# Replay Memory size: 350
#
# ____________________________________________________________________________________________
# Episode 155 Done!
# Episode reward: -1449.0
# Epsilon: 0.9230000000000085
# Replay Memory size: 246
#
# ____________________________________________________________________________________________
# Episode 156 Done!
# Episode reward: -550.0
# Epsilon: 0.9225000000000085
# Replay Memory size: 286
#
# ____________________________________________________________________________________________
# Episode 157 Done!
# Episode reward: -600.0
# Epsilon: 0.9220000000000086
# Replay Memory size: 262
#
# ____________________________________________________________________________________________
# Episode 158 Done!
# Episode reward: -550.0
# Epsilon: 0.9215000000000086
# Replay Memory size: 238
#
# ____________________________________________________________________________________________
# Episode 159 Done!
# Episode reward: -550.0
# Epsilon: 0.9210000000000087
# Replay Memory size: 310
#
# ____________________________________________________________________________________________
# Episode 160 Done!
# Episode reward: -550.0
# Epsilon: 0.9205000000000088
# Replay Memory size: 286
#
# ____________________________________________________________________________________________
# Episode 161 Done!
# Episode reward: -1444.0
# Epsilon: 0.9200000000000088
# Replay Memory size: 229
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 162 Done!
# Episode reward: -500.0
# Epsilon: 0.9195000000000089
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 163 Done!
# Episode reward: -500.0
# Epsilon: 0.9190000000000089
# Replay Memory size: 245
#
# ____________________________________________________________________________________________
# Episode 164 Done!
# Episode reward: -550.0
# Epsilon: 0.918500000000009
# Replay Memory size: 253
#
# ____________________________________________________________________________________________
# Episode 165 Done!
# Episode reward: -600.0
# Epsilon: 0.918000000000009
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 166 Done!
# Episode reward: -921.0
# Epsilon: 0.9175000000000091
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 167 Done!
# Episode reward: -600.0
# Epsilon: 0.9170000000000091
# Replay Memory size: 405
#
# ____________________________________________________________________________________________
# Episode 168 Done!
# Episode reward: -450.0
# Epsilon: 0.9165000000000092
# Replay Memory size: 349
#
# ____________________________________________________________________________________________
# Episode 169 Done!
# Episode reward: -600.0
# Epsilon: 0.9160000000000093
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 170 Done!
# Episode reward: -600.0
# Epsilon: 0.9155000000000093
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 171 Done!
# Episode reward: -550.0
# Epsilon: 0.9150000000000094
# Replay Memory size: 373
#
# ____________________________________________________________________________________________
# Episode 172 Done!
# Episode reward: -1266.0
# Epsilon: 0.9145000000000094
# Replay Memory size: 336
#
# ____________________________________________________________________________________________
# Episode 173 Done!
# Episode reward: -1413.0
# Epsilon: 0.9140000000000095
# Replay Memory size: 348
#
# ____________________________________________________________________________________________
# Episode 174 Done!
# Episode reward: -1398.0
# Epsilon: 0.9135000000000095
# Replay Memory size: 259
#
# ____________________________________________________________________________________________
# Episode 175 Done!
# Episode reward: -550.0
# Epsilon: 0.9130000000000096
# Replay Memory size: 203
#
# ____________________________________________________________________________________________
# Episode 176 Done!
# Episode reward: -600.0
# Epsilon: 0.9125000000000096
# Replay Memory size: 275
#
# ____________________________________________________________________________________________
# Episode 177 Done!
# Episode reward: -500.0
# Epsilon: 0.9120000000000097
# Replay Memory size: 283
#
# ____________________________________________________________________________________________
# Episode 178 Done!
# Episode reward: -500.0
# Epsilon: 0.9115000000000097
# Replay Memory size: 227
#
# ____________________________________________________________________________________________
# Episode 179 Done!
# Episode reward: -600.0
# Epsilon: 0.9110000000000098
# Replay Memory size: 267
#
# ____________________________________________________________________________________________
# Episode 180 Done!
# Episode reward: -500.0
# Epsilon: 0.9105000000000099
# Replay Memory size: 339
#
# ____________________________________________________________________________________________
# Episode 181 Done!
# Episode reward: -550.0
# Epsilon: 0.9100000000000099
# Replay Memory size: 283
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 182 Done!
# Episode reward: -1476.0
# Epsilon: 0.90950000000001
# Replay Memory size: 284
#
# ____________________________________________________________________________________________
# Episode 183 Done!
# Episode reward: -500.0
# Epsilon: 0.90900000000001
# Replay Memory size: 260
#
# ____________________________________________________________________________________________
# Episode 184 Done!
# Episode reward: -1096.0
# Epsilon: 0.9085000000000101
# Replay Memory size: 279
#
# ____________________________________________________________________________________________
# Episode 185 Done!
# Episode reward: -1464.0
# Epsilon: 0.9080000000000101
# Replay Memory size: 372
#
# ____________________________________________________________________________________________
# Episode 186 Done!
# Episode reward: -1335.0
# Epsilon: 0.9075000000000102
# Replay Memory size: 326
#
# ____________________________________________________________________________________________
# Episode 187 Done!
# Episode reward: -996.0
# Epsilon: 0.9070000000000102
# Replay Memory size: 327
#
# ____________________________________________________________________________________________
# Episode 188 Done!
# Episode reward: -1209.0
# Epsilon: 0.9065000000000103
# Replay Memory size: 207
#
# ____________________________________________________________________________________________
# Episode 189 Done!
# Episode reward: -550.0
# Epsilon: 0.9060000000000104
# Replay Memory size: 311
#
# ____________________________________________________________________________________________
# Episode 190 Done!
# Episode reward: -1234.0
# Epsilon: 0.9055000000000104
# Replay Memory size: 312
#
# ____________________________________________________________________________________________
# Episode 191 Done!
# Episode reward: -1140.0
# Epsilon: 0.9050000000000105
# Replay Memory size: 361
#
# ____________________________________________________________________________________________
# Episode 192 Done!
# Episode reward: -550.0
# Epsilon: 0.9045000000000105
# Replay Memory size: 337
#
# ____________________________________________________________________________________________
# Episode 193 Done!
# Episode reward: -550.0
# Epsilon: 0.9040000000000106
# Replay Memory size: 409
#
# ____________________________________________________________________________________________
# Episode 194 Done!
# Episode reward: -960.0
# Epsilon: 0.9035000000000106
# Replay Memory size: 448
#
# ____________________________________________________________________________________________
# Episode 195 Done!
# Episode reward: -550.0
# Epsilon: 0.9030000000000107
# Replay Memory size: 360
#
# ____________________________________________________________________________________________
# Episode 196 Done!
# Episode reward: -1362.0
# Epsilon: 0.9025000000000107
# Replay Memory size: 291
#
# ____________________________________________________________________________________________
# Episode 197 Done!
# Episode reward: -1289.0
# Epsilon: 0.9020000000000108
# Replay Memory size: 263
#
# ____________________________________________________________________________________________
# Episode 198 Done!
# Episode reward: -1344.0
# Epsilon: 0.9015000000000108
# Replay Memory size: 252
#
# ____________________________________________________________________________________________
# Episode 199 Done!
# Episode reward: -1380.0
# Epsilon: 0.9010000000000109
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 200 Done!
# Episode reward: -1041.0
# Epsilon: 0.900500000000011
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 201 Done!
# Episode reward: -550.0
# Epsilon: 0.900000000000011
# Replay Memory size: 245
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 202 Done!
# Episode reward: -600.0
# Epsilon: 0.8995000000000111
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 203 Done!
# Episode reward: -1299.0
# Epsilon: 0.8990000000000111
# Replay Memory size: 355
#
# ____________________________________________________________________________________________
# Episode 204 Done!
# Episode reward: -1354.0
# Epsilon: 0.8985000000000112
# Replay Memory size: 364
#
# ____________________________________________________________________________________________
# Episode 205 Done!
# Episode reward: -600.0
# Epsilon: 0.8980000000000112
# Replay Memory size: 372
#
# ____________________________________________________________________________________________
# Episode 206 Done!
# Episode reward: -1425.0
# Epsilon: 0.8975000000000113
# Replay Memory size: 356
#
# ____________________________________________________________________________________________
# Episode 207 Done!
# Episode reward: -1020.0
# Epsilon: 0.8970000000000113
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 208 Done!
# Episode reward: -500.0
# Epsilon: 0.8965000000000114
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 209 Done!
# Episode reward: -600.0
# Epsilon: 0.8960000000000115
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 210 Done!
# Episode reward: -550.0
# Epsilon: 0.8955000000000115
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 211 Done!
# Episode reward: -550.0
# Epsilon: 0.8950000000000116
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 212 Done!
# Episode reward: -500.0
# Epsilon: 0.8945000000000116
# Replay Memory size: 181
#
# ____________________________________________________________________________________________
# Episode 213 Done!
# Episode reward: -600.0
# Epsilon: 0.8940000000000117
# Replay Memory size: 157
#
# ____________________________________________________________________________________________
# Episode 214 Done!
# Episode reward: -1434.0
# Epsilon: 0.8935000000000117
# Replay Memory size: 176
#
# ____________________________________________________________________________________________
# Episode 215 Done!
# Episode reward: -1347.0
# Epsilon: 0.8930000000000118
# Replay Memory size: 166
#
# ____________________________________________________________________________________________
# Episode 216 Done!
# Episode reward: -1359.0
# Epsilon: 0.8925000000000118
# Replay Memory size: 192
#
# ____________________________________________________________________________________________
# Episode 217 Done!
# Episode reward: -550.0
# Epsilon: 0.8920000000000119
# Replay Memory size: 264
#
# ____________________________________________________________________________________________
# Episode 218 Done!
# Episode reward: -1154.0
# Epsilon: 0.891500000000012
# Replay Memory size: 319
#
# ____________________________________________________________________________________________
# Episode 219 Done!
# Episode reward: -600.0
# Epsilon: 0.891000000000012
# Replay Memory size: 391
#
# ____________________________________________________________________________________________
# Episode 220 Done!
# Episode reward: -550.0
# Epsilon: 0.8905000000000121
# Replay Memory size: 495
#
# ____________________________________________________________________________________________
# Episode 221 Done!
# Episode reward: -1203.0
# Epsilon: 0.8900000000000121
# Replay Memory size: 469
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 222 Done!
# Episode reward: -500.0
# Epsilon: 0.8895000000000122
# Replay Memory size: 413
#
# ____________________________________________________________________________________________
# Episode 223 Done!
# Episode reward: -600.0
# Epsilon: 0.8890000000000122
# Replay Memory size: 357
#
# ____________________________________________________________________________________________
# Episode 224 Done!
# Episode reward: -1281.0
# Epsilon: 0.8885000000000123
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 225 Done!
# Episode reward: -1387.0
# Epsilon: 0.8880000000000123
# Replay Memory size: 281
#
# ____________________________________________________________________________________________
# Episode 226 Done!
# Episode reward: -1245.0
# Epsilon: 0.8875000000000124
# Replay Memory size: 333
#
# ____________________________________________________________________________________________
# Episode 227 Done!
# Episode reward: -1374.0
# Epsilon: 0.8870000000000124
# Replay Memory size: 300
#
# ____________________________________________________________________________________________
# Episode 228 Done!
# Episode reward: -500.0
# Epsilon: 0.8865000000000125
# Replay Memory size: 372
#
# ____________________________________________________________________________________________
# Episode 229 Done!
# Episode reward: -1338.0
# Epsilon: 0.8860000000000126
# Replay Memory size: 359
#
# ____________________________________________________________________________________________
# Episode 230 Done!
# Episode reward: -550.0
# Epsilon: 0.8855000000000126
# Replay Memory size: 239
#
# ____________________________________________________________________________________________
# Episode 231 Done!
# Episode reward: -1203.0
# Epsilon: 0.8850000000000127
# Replay Memory size: 245
#
# ____________________________________________________________________________________________
# Episode 232 Done!
# Episode reward: -500.0
# Epsilon: 0.8845000000000127
# Replay Memory size: 157
#
# ____________________________________________________________________________________________
# Episode 233 Done!
# Episode reward: -550.0
# Epsilon: 0.8840000000000128
# Replay Memory size: 165
#
# ____________________________________________________________________________________________
# Episode 234 Done!
# Episode reward: -1434.0
# Epsilon: 0.8835000000000128
# Replay Memory size: 216
#
# ____________________________________________________________________________________________
# Episode 235 Done!
# Episode reward: -600.0
# Epsilon: 0.8830000000000129
# Replay Memory size: 224
#
# ____________________________________________________________________________________________
# Episode 236 Done!
# Episode reward: -1440.0
# Epsilon: 0.8825000000000129
# Replay Memory size: 149
#
# ____________________________________________________________________________________________
# Episode 237 Done!
# Episode reward: -1275.0
# Epsilon: 0.882000000000013
# Replay Memory size: 211
#
# ____________________________________________________________________________________________
# Episode 238 Done!
# Episode reward: -550.0
# Epsilon: 0.881500000000013
# Replay Memory size: 251
#
# ____________________________________________________________________________________________
# Episode 239 Done!
# Episode reward: -500.0
# Epsilon: 0.8810000000000131
# Replay Memory size: 355
#
# ____________________________________________________________________________________________
# Episode 240 Done!
# Episode reward: -1132.0
# Epsilon: 0.8805000000000132
# Replay Memory size: 354
#
# ____________________________________________________________________________________________
# Episode 241 Done!
# Episode reward: -1070.0
# Epsilon: 0.8800000000000132
# Replay Memory size: 317
#
# ...
# Episode 637 Done!
# Episode reward: -500.0
# Epsilon: 0.682000000000035
# Replay Memory size: 382
#
# ____________________________________________________________________________________________
# Episode 638 Done!
# Episode reward: -600.0
# Epsilon: 0.6815000000000351
# Replay Memory size: 230
#
# ____________________________________________________________________________________________
# Episode 639 Done!
# Episode reward: -500.0
# Epsilon: 0.6810000000000351
# Replay Memory size: 302
#
# ____________________________________________________________________________________________
# Episode 640 Done!
# Episode reward: -550.0
# Epsilon: 0.6805000000000352
# Replay Memory size: 374
#
# ____________________________________________________________________________________________
# Episode 641 Done!
# Episode reward: -500.0
# Epsilon: 0.6800000000000352
# Replay Memory size: 510
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# /content/drive/My Drive/snakeAI/Snake/utils.py:56: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, (ax1, ax2) = plt.subplots(2, 1)
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 642 Done!
# Episode reward: -550.0
# Epsilon: 0.6795000000000353
# Replay Memory size: 454
#
# ____________________________________________________________________________________________
# Episode 643 Done!
# Episode reward: -1392.0
# Epsilon: 0.6790000000000354
# Replay Memory size: 491
#
# ____________________________________________________________________________________________
# Episode 644 Done!
# Episode reward: -1080.0
# Epsilon: 0.6785000000000354
# Replay Memory size: 378
#
# ____________________________________________________________________________________________
# Episode 645 Done!
# Episode reward: -1320.0
# Epsilon: 0.6780000000000355
# Replay Memory size: 455
#
# ____________________________________________________________________________________________
# Episode 646 Done!
# Episode reward: -450.0
# Epsilon: 0.6775000000000355
# Replay Memory size: 495
#
# ____________________________________________________________________________________________
# Episode 647 Done!
# Episode reward: -550.0
# Epsilon: 0.6770000000000356
# Replay Memory size: 599
#
# ____________________________________________________________________________________________
# Episode 648 Done!
# Episode reward: -500.0
# Epsilon: 0.6765000000000356
# Replay Memory size: 287
#
# ____________________________________________________________________________________________
# Episode 649 Done!
# Episode reward: -550.0
# Epsilon: 0.6760000000000357
# Replay Memory size: 263
#
# ____________________________________________________________________________________________
# Episode 650 Done!
# Episode reward: -550.0
# Epsilon: 0.6755000000000357
# Replay Memory size: 239
#
# ____________________________________________________________________________________________
# Episode 651 Done!
# Episode reward: -1320.0
# Epsilon: 0.6750000000000358
# Replay Memory size: 220
#
# ____________________________________________________________________________________________
# Episode 652 Done!
# Episode reward: -1197.0
# Epsilon: 0.6745000000000358
# Replay Memory size: 210
#
# ____________________________________________________________________________________________
# Episode 653 Done!
# Episode reward: -600.0
# Epsilon: 0.6740000000000359
# Replay Memory size: 282
#
# ____________________________________________________________________________________________
# Episode 654 Done!
# Episode reward: -550.0
# Epsilon: 0.673500000000036
# Replay Memory size: 322
#
# ____________________________________________________________________________________________
# Episode 655 Done!
# Episode reward: -600.0
# Epsilon: 0.673000000000036
# Replay Memory size: 330
#
# ____________________________________________________________________________________________
# Episode 656 Done!
# Episode reward: -550.0
# Epsilon: 0.6725000000000361
# Replay Memory size: 338
#
# ____________________________________________________________________________________________
# Episode 657 Done!
# Episode reward: -1022.0
# Epsilon: 0.6720000000000361
# Replay Memory size: 381
#
# ____________________________________________________________________________________________
# Episode 658 Done!
# Episode reward: -1390.0
# Epsilon: 0.6715000000000362
# Replay Memory size: 306
#
# ____________________________________________________________________________________________
# Episode 659 Done!
# Episode reward: -450.0
# Epsilon: 0.6710000000000362
# Replay Memory size: 250
#
# ____________________________________________________________________________________________
# Episode 660 Done!
# Episode reward: -1131.0
# Epsilon: 0.6705000000000363
# Replay Memory size: 232
#
# ____________________________________________________________________________________________
# Episode 661 Done!
# Episode reward: -600.0
# Epsilon: 0.6700000000000363
# Replay Memory size: 336
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# /content/drive/My Drive/snakeAI/Snake/utils.py:56: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, (ax1, ax2) = plt.subplots(2, 1)
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 662 Done!
# Episode reward: -600.0
# Epsilon: 0.6695000000000364
# Replay Memory size: 248
#
# ____________________________________________________________________________________________
# Episode 663 Done!
# Episode reward: -550.0
# Epsilon: 0.6690000000000365
# Replay Memory size: 320
#
# ____________________________________________________________________________________________
# Episode 664 Done!
# Episode reward: -550.0
# Epsilon: 0.6685000000000365
# Replay Memory size: 264
#
# ____________________________________________________________________________________________
# Episode 665 Done!
# Episode reward: -450.0
# Epsilon: 0.6680000000000366
# Replay Memory size: 272
#
# ____________________________________________________________________________________________
# Episode 666 Done!
# Episode reward: -1407.0
# Epsilon: 0.6675000000000366
# Replay Memory size: 282
#
# ____________________________________________________________________________________________
# Episode 667 Done!
# Episode reward: -550.0
# Epsilon: 0.6670000000000367
# Replay Memory size: 322
#
# ____________________________________________________________________________________________
# Episode 668 Done!
# Episode reward: -500.0
# Epsilon: 0.6665000000000367
# Replay Memory size: 394
#
# ____________________________________________________________________________________________
# Episode 669 Done!
# Episode reward: -1050.0
# Epsilon: 0.6660000000000368
# Replay Memory size: 413
#
# ____________________________________________________________________________________________
# Episode 670 Done!
# Episode reward: -1455.0
# Epsilon: 0.6655000000000368
# Replay Memory size: 279
#
# ____________________________________________________________________________________________
# Episode 671 Done!
# Episode reward: -600.0
# Epsilon: 0.6650000000000369
# Replay Memory size: 351
#
# ____________________________________________________________________________________________
# Episode 672 Done!
# Episode reward: -1200.0
# Epsilon: 0.664500000000037
# Replay Memory size: 388
#
# ____________________________________________________________________________________________
# Episode 673 Done!
# Episode reward: -1071.0
# Epsilon: 0.664000000000037
# Replay Memory size: 350
#
# ____________________________________________________________________________________________
# Episode 674 Done!
# Episode reward: -1288.0
# Epsilon: 0.6635000000000371
# Replay Memory size: 337
#
# ____________________________________________________________________________________________
# Episode 675 Done!
# Episode reward: -400.0
# Epsilon: 0.6630000000000371
# Replay Memory size: 313
#
# ____________________________________________________________________________________________
# Episode 676 Done!
# Episode reward: -550.0
# Epsilon: 0.6625000000000372
# Replay Memory size: 353
#
# ____________________________________________________________________________________________
# Episode 677 Done!
# Episode reward: -550.0
# Epsilon: 0.6620000000000372
# Replay Memory size: 457
#
# ____________________________________________________________________________________________
# Episode 678 Done!
# Episode reward: -550.0
# Epsilon: 0.6615000000000373
# Replay Memory size: 401
#
# ____________________________________________________________________________________________
# Episode 679 Done!
# Episode reward: -550.0
# Epsilon: 0.6610000000000373
# Replay Memory size: 345
#
# ____________________________________________________________________________________________
# Episode 680 Done!
# Episode reward: -1237.0
# Epsilon: 0.6605000000000374
# Replay Memory size: 379
#
# ____________________________________________________________________________________________
# Episode 681 Done!
# Episode reward: -550.0
# Epsilon: 0.6600000000000374
# Replay Memory size: 387
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# /content/drive/My Drive/snakeAI/Snake/utils.py:56: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, (ax1, ax2) = plt.subplots(2, 1)
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 682 Done!
# Episode reward: -1407.0
# Epsilon: 0.6595000000000375
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 683 Done!
# Episode reward: -600.0
# Epsilon: 0.6590000000000376
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 684 Done!
# Episode reward: -550.0
# Epsilon: 0.6585000000000376
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 685 Done!
# Episode reward: -550.0
# Epsilon: 0.6580000000000377
# Replay Memory size: 229
#
# ____________________________________________________________________________________________
# Episode 686 Done!
# Episode reward: -500.0
# Epsilon: 0.6575000000000377
# Replay Memory size: 301
#
# ____________________________________________________________________________________________
# Episode 687 Done!
# Episode reward: -550.0
# Epsilon: 0.6570000000000378
# Replay Memory size: 213
#
# ____________________________________________________________________________________________
# Episode 688 Done!
# Episode reward: -600.0
# Epsilon: 0.6565000000000378
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 689 Done!
# Episode reward: -550.0
# Epsilon: 0.6560000000000379
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 690 Done!
# Episode reward: -1377.0
# Epsilon: 0.6555000000000379
# Replay Memory size: 389
#
# ____________________________________________________________________________________________
# Episode 691 Done!
# Episode reward: -550.0
# Epsilon: 0.655000000000038
# Replay Memory size: 333
#
# ____________________________________________________________________________________________
# Episode 692 Done!
# Episode reward: -450.0
# Epsilon: 0.654500000000038
# Replay Memory size: 341
#
# ____________________________________________________________________________________________
# Episode 693 Done!
# Episode reward: -550.0
# Epsilon: 0.6540000000000381
# Replay Memory size: 381
#
# ____________________________________________________________________________________________
# Episode 694 Done!
# Episode reward: -550.0
# Epsilon: 0.6535000000000382
# Replay Memory size: 453
#
# ____________________________________________________________________________________________
# Episode 695 Done!
# Episode reward: -1251.0
# Epsilon: 0.6530000000000382
# Replay Memory size: 443
#
# ____________________________________________________________________________________________
# Episode 696 Done!
# Episode reward: -1143.0
# Epsilon: 0.6525000000000383
# Replay Memory size: 461
#
# ____________________________________________________________________________________________
# Episode 697 Done!
# Episode reward: -550.0
# Epsilon: 0.6520000000000383
# Replay Memory size: 277
#
# ____________________________________________________________________________________________
# Episode 698 Done!
# Episode reward: -550.0
# Epsilon: 0.6515000000000384
# Replay Memory size: 285
#
# ____________________________________________________________________________________________
# Episode 699 Done!
# Episode reward: -600.0
# Epsilon: 0.6510000000000384
# Replay Memory size: 261
#
# ____________________________________________________________________________________________
# Episode 700 Done!
# Episode reward: -500.0
# Epsilon: 0.6505000000000385
# Replay Memory size: 365
#
# ____________________________________________________________________________________________
# Episode 701 Done!
# Episode reward: -600.0
# Epsilon: 0.6500000000000385
# Replay Memory size: 341
#
# Model saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/model
# /content/drive/My Drive/snakeAI/Snake/utils.py:56: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, (ax1, ax2) = plt.subplots(2, 1)
# Graph saved at: drive/My Drive/snakeAI/trainings/transfer_learningDQN/ResNet50/10Jun2020__200157933012/Reward.png
# ____________________________________________________________________________________________
# Episode 702 Done!
# Episode reward: -500.0
# Epsilon: 0.6495000000000386
# Replay Memory size: 317
#
# ____________________________________________________________________________________________
# Episode 703 Done!
# Episode reward: -500.0
# Epsilon: 0.6490000000000387
# Replay Memory size: 325
#
# ____________________________________________________________________________________________
# Episode 704 Done!
# Episode reward: -550.0
# Epsilon: 0.6485000000000387
# Replay Memory size: 269
#
# ____________________________________________________________________________________________
# Episode 705 Done!
# Episode reward: -1470.0
# Epsilon: 0.6480000000000388
# Replay Memory size: 300
#
# ____________________________________________________________________________________________
# Episode 706 Done!
# Episode reward: -550.0
# Epsilon: 0.6475000000000388
# Replay Memory size: 212
#
# ____________________________________________________________________________________________
# Episode 707 Done!
# Episode reward: -1192.0
# Epsilon: 0.6470000000000389
# Replay Memory size: 199
#
# ____________________________________________________________________________________________
# Episode 708 Done!
# Episode reward: -500.0
# Epsilon: 0.6465000000000389
# Replay Memory size: 175
#
# ____________________________________________________________________________________________
# Episode 709 Done!
# Episode reward: -1248.0
# Epsilon: 0.646000000000039
# Replay Memory size: 260
#
# ____________________________________________________________________________________________

# %%
assert False
env = SnakeMaze(20, 20, 1, with_boundaries=False)
env.reset()
imgs = []
while env.num_active_agents:
    imgs.append(env.snake_matrices[0])
    # state = resize_image(env.snake_matrices[0], IMAGE_SIZE)
    direction = np.argmax(model(np.array([state])))
    env.step({0: direction})

# %%
generate_animation(imgs)
